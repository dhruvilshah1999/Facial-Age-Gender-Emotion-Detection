# %% [markdown]
# # Age Estimation using VGG16

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from tensorflow.keras.models import load_model

import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from collections import Counter
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.utils import shuffle

import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm.notebook import tqdm

# %matplotlib inline

from PIL import Image
import shutil

# %% [markdown]
# ## Age estimation in age groups

# %% [markdown]
# ### Set image size and variables

# %%
IMAGE_SIZE = [224,224]
TRAIN_TEST_SPLIT = 0.3
BASE_DIR = '../input/utkface-new/UTKFace/'
NR_EPOCHS = 60

# %% [markdown]
# ### Define methods map direct age to classes

# %%
def age_to_class( age ):
    age_class = None
    if 0 <= age <= 20:
        age_class = 0
    if 20 < age <= 25:
        age_class = 1
    if 25 < age <= 30:
        age_class = 2
    if 30 < age <= 40:
        age_class = 3
    if 40 < age <= 60:
        age_class = 4
    if age > 60:
        age_class = 5
    return age_class

age_dict = {0:'0-20', 1:'20-25',2:'25-30', 3:'30-40', 4:'40-60', 5:'60+'}

def decode_age_label(age_id):
    return age_dict[int(age_id)]

# %% [markdown]
# ### Read input dataset

# %%
# read labels of image age, gender
image_paths = []
age_labels = []
gender_labels =[]
age_class = []

for filename in tqdm(os.listdir(BASE_DIR)):
  #read image path
  image_path = os.path.join(BASE_DIR, filename)
  #split filename to extract labels
  temp= filename.split('_')
  age = int(temp[0])
  gender = int(temp[1])
  image_paths.append(image_path)
  age_labels.append(age)
  gender_labels.append(gender)
  age_class.append(age_to_class(age))

# extract name of file 
names = []
for path in image_paths:
  temp = path.split('/')
  names.append(temp[4])

#convert to dataframe
df = pd.DataFrame()
df['image'], df['age'], df['gender'], df['age_class'], df['name'] = image_paths, age_labels, gender_labels, age_class, names
df.head()
df

# get and print the number of images in dataframe
age_verbose = [age_dict[int(age)] for age in df['age_class']]

print(Counter(age_verbose))
# Out:
#   0%|          | 0/23708 [00:00<?, ?it/s]
# Counter({'25-30': 5024, '0-20': 4877, '30-40': 4339, '40-60': 4311, '20-25': 2760, '60+': 2397})

# %% [markdown]
# ### Shuffle dataset

# %%
# shuffle dataset 
df = shuffle(df)

# %%
# check dataframe
df
# Out:
#                                                    image  age  gender  \
# 13163  ../input/utkface-new/UTKFace/22_1_2_2017011616...   22       1
# 6750   ../input/utkface-new/UTKFace/31_1_4_2017010323...   31       1
# 22957  ../input/utkface-new/UTKFace/44_0_3_2017011919...   44       0
# 2071   ../input/utkface-new/UTKFace/20_0_4_2017011719...   20       0
# 21126  ../input/utkface-new/UTKFace/23_1_0_2017010318...   23       1
# ...                                                  ...  ...     ...
# 3392   ../input/utkface-new/UTKFace/25_0_3_2017011915...   25       0
# 14537  ../input/utkface-new/UTKFace/50_0_0_2017011716...   50       0
# 6557   ../input/utkface-new/UTKFace/18_0_0_2017011714...   18       0
# 19300  ../input/utkface-new/UTKFace/21_0_1_2017011621...   21       0
# 13295  ../input/utkface-new/UTKFace/1_0_0_20161219140...    1       0
#
#        age_class                                   name
# 13163          1  22_1_2_20170116165605354.jpg.chip.jpg
# 6750           3  31_1_4_20170103230411344.jpg.chip.jpg
# 22957          4  44_0_3_20170119195204451.jpg.chip.jpg
# 2071           0  20_0_4_20170117193449429.jpg.chip.jpg
# 21126          1  23_1_0_20170103180518664.jpg.chip.jpg
# ...          ...                                    ...
# 3392           1  25_0_3_20170119153348729.jpg.chip.jpg
# 14537          4  50_0_0_20170117160624326.jpg.chip.jpg
# 6557           0  18_0_0_20170117140123048.jpg.chip.jpg
# 19300          1  21_0_1_20170116215541940.jpg.chip.jpg
# 13295          0   1_0_0_20161219140627985.jpg.chip.jpg
#
# [23708 rows x 5 columns]

# %% [markdown]
# ### Split Dataset into validation and test set

# %%
training_data = df.sample(frac=0.8, random_state=25)
temp = df.drop(training_data.index)


val_data =  temp.sample(frac=0.7, random_state=25)
testing_data = temp.drop(val_data.index)

 
print(f"No. of training examples: {training_data.shape[0]}")
print(f"No. of training examples: {val_data.shape[0]}")
print(f"No. of testing examples: {testing_data.shape[0]}")
# Out:
# No. of training examples: 18966
# No. of training examples: 3319
# No. of testing examples: 1423

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(rescale=1./255,
                               preprocessing_function=preprocess_input)

val_datagen = ImageDataGenerator(rescale=1./255,
                                preprocessing_function=preprocess_input)


CLASS_MODE = 'raw'
BATCH_SIZE = 64
BASE_DIR = '../input/utkface-new/UTKFace'

train_generator = train_datagen.flow_from_dataframe(dataframe=training_data, 
                                                directory=BASE_DIR, 
                                                x_col='name', 
                                                y_col='age_class', 
                                                class_mode=CLASS_MODE,
                                                batch_size=BATCH_SIZE, 
                                                shuffle=True, 
                                                target_size=IMAGE_SIZE)



val_generator = val_datagen.flow_from_dataframe(dataframe=val_data, 
                                              directory=BASE_DIR, 
                                              x_col='name', 
                                              y_col='age_class', 
                                              class_mode=CLASS_MODE, 
                                              batch_size=BATCH_SIZE,
                                              shuffle=False, 
                                              target_size=IMAGE_SIZE)

test_generator = val_datagen.flow_from_dataframe(dataframe=testing_data, 
                                              directory=BASE_DIR, 
                                              x_col='name', 
                                              y_col='age_class', 
                                              class_mode=CLASS_MODE, 
                                              batch_size=BATCH_SIZE,
                                              shuffle=False, 
                                              target_size=IMAGE_SIZE)
# Out:
# Found 18966 validated image filenames.
# Found 3319 validated image filenames.
# Found 1423 validated image filenames.

# %%
from pathlib import Path
path = Path("./models")
path.mkdir(exist_ok=True)


MODEL_PATH = "./models/age_best_model.h5"


checkpoint = tf.keras.callbacks.ModelCheckpoint(MODEL_PATH, 
                                                monitor='val_sparse_categorical_accuracy', 
                                                verbose=1, 
                                                save_best_only=True, 
                                                mode='max')

import datetime
log_dir = '../tblogs/age_model_' + datetime.datetime.now().strftime('%y-%m-%d_%H-%M')
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=0)
# Out:
# 2022-12-14 20:14:41.792551: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-12-14 20:14:41.793011: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-12-14 20:14:41.850828: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1614] Profiler found 1 GPUs
# 2022-12-14 20:14:41.885725: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-12-14 20:14:41.885890: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed

# %% [markdown]
# ### Build and load Model

# %%
# # detect and init the TPU
# tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()

# # instantiate a distribution strategy
# tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

# %%
# load VGG16 without the last 3 Dense layers, in order to train these new
vgg = VGG16(input_shape = IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# check if input type is correct
vgg.inputs
# Out:
# 2022-12-14 20:14:42.048955: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:14:42.144958: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:14:42.145859: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:14:42.146826: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-14 20:14:42.147135: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:14:42.147826: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:14:42.148457: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:14:44.406958: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:14:44.407833: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:14:44.408498: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:14:44.409086: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# [<KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'input_1')>]

# %%
from keras.layers import *
for layer in vgg.layers:
  layer.trainable = False


x = Flatten()(vgg.output)
x = Dense(4096, activation='relu')(x)
x = Dense(4096, activation='relu')(x)
prediction = Dense(6, activation='softmax')(x)
model = Model(inputs=vgg.input, outputs=prediction)
    
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 24582
# =================================================================
# Total params: 134,285,126
# Trainable params: 119,570,438
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras import callbacks

earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 5, 
                                        restore_best_weights = True)

history = model.fit(train_generator,
                    epochs=NR_EPOCHS,
                    validation_data=val_generator,
                    callbacks = [tensorboard_callback, checkpoint]
                    )
# Out:
# 2022-12-14 20:14:46.138856: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/60
# 2022-12-14 20:14:48.080291: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
#   1/297 [..............................] - ETA: 59:55 - loss: 1.9771 - sparse_categorical_accuracy: 0.1562
# 2022-12-14 20:14:58.340061: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-12-14 20:14:58.340103: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
#   2/297 [..............................] - ETA: 2:25 - loss: 19.1748 - sparse_categorical_accuracy: 0.1719
# 2022-12-14 20:14:58.816065: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-12-14 20:14:58.816615: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed
# 2022-12-14 20:14:58.954733: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:673]  GpuTracer has collected 145 callback api events and 142 activity events.
# 2022-12-14 20:14:58.961287: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-12-14 20:14:58.981669: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ../tblogs/age_model_22-12-14_20-14/train/plugins/profile/2022_12_14_20_14_58
#
# 2022-12-14 20:14:58.989764: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to ../tblogs/age_model_22-12-14_20-14/train/plugins/profile/2022_12_14_20_14_58/25bf8713874b.trace.json.gz
# 2022-12-14 20:14:59.021784: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ../tblogs/age_model_22-12-14_20-14/train/plugins/profile/2022_12_14_20_14_58
#
# 2022-12-14 20:14:59.025053: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to ../tblogs/age_model_22-12-14_20-14/train/plugins/profile/2022_12_14_20_14_58/25bf8713874b.memory_profile.json.gz
# 2022-12-14 20:14:59.026501: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: ../tblogs/age_model_22-12-14_20-14/train/plugins/profile/2022_12_14_20_14_58
# Dumped tool data for xplane.pb to ../tblogs/age_model_22-12-14_20-14/train/plugins/profile/2022_12_14_20_14_58/25bf8713874b.xplane.pb
# Dumped tool data for overview_page.pb to ../tblogs/age_model_22-12-14_20-14/train/plugins/profile/2022_12_14_20_14_58/25bf8713874b.overview_page.pb
# Dumped tool data for input_pipeline.pb to ../tblogs/age_model_22-12-14_20-14/train/plugins/profile/2022_12_14_20_14_58/25bf8713874b.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to ../tblogs/age_model_22-12-14_20-14/train/plugins/profile/2022_12_14_20_14_58/25bf8713874b.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to ../tblogs/age_model_22-12-14_20-14/train/plugins/profile/2022_12_14_20_14_58/25bf8713874b.kernel_stats.pb
# 297/297 [==============================] - 188s 594ms/step - loss: 1.8075 - sparse_categorical_accuracy: 0.4688 - val_loss: 1.1769 - val_sparse_categorical_accuracy: 0.4887
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.48870, saving model to ./models/age_best_model.h5
# Epoch 2/60
# 297/297 [==============================] - 82s 274ms/step - loss: 1.0427 - sparse_categorical_accuracy: 0.5477 - val_loss: 1.0881 - val_sparse_categorical_accuracy: 0.5348
#
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.48870 to 0.53480, saving model to ./models/age_best_model.h5
# Epoch 3/60
# 297/297 [==============================] - 74s 250ms/step - loss: 0.9718 - sparse_categorical_accuracy: 0.5810 - val_loss: 1.0748 - val_sparse_categorical_accuracy: 0.5348
#
# Epoch 00003: val_sparse_categorical_accuracy did not improve from 0.53480
# Epoch 4/60
# 297/297 [==============================] - 92s 310ms/step - loss: 0.9017 - sparse_categorical_accuracy: 0.6134 - val_loss: 1.1011 - val_sparse_categorical_accuracy: 0.5520
#
# Epoch 00004: val_sparse_categorical_accuracy improved from 0.53480 to 0.55197, saving model to ./models/age_best_model.h5
# Epoch 5/60
# 297/297 [==============================] - 83s 281ms/step - loss: 0.8303 - sparse_categorical_accuracy: 0.6472 - val_loss: 1.0864 - val_sparse_categorical_accuracy: 0.5402
#
# Epoch 00005: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 6/60
# 297/297 [==============================] - 83s 280ms/step - loss: 0.7831 - sparse_categorical_accuracy: 0.6709 - val_loss: 1.1836 - val_sparse_categorical_accuracy: 0.5363
#
# Epoch 00006: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 7/60
# 297/297 [==============================] - 84s 281ms/step - loss: 0.7571 - sparse_categorical_accuracy: 0.6783 - val_loss: 1.2156 - val_sparse_categorical_accuracy: 0.5423
#
# Epoch 00007: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 8/60
# 297/297 [==============================] - 83s 281ms/step - loss: 0.6690 - sparse_categorical_accuracy: 0.7217 - val_loss: 1.2843 - val_sparse_categorical_accuracy: 0.5288
#
# Epoch 00008: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 9/60
# 297/297 [==============================] - 84s 281ms/step - loss: 0.6317 - sparse_categorical_accuracy: 0.7377 - val_loss: 1.3392 - val_sparse_categorical_accuracy: 0.5249
#
# Epoch 00009: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 10/60
# 297/297 [==============================] - 80s 271ms/step - loss: 0.5731 - sparse_categorical_accuracy: 0.7682 - val_loss: 1.4247 - val_sparse_categorical_accuracy: 0.5110
#
# Epoch 00010: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 11/60
# 297/297 [==============================] - 75s 251ms/step - loss: 0.5386 - sparse_categorical_accuracy: 0.7827 - val_loss: 1.4088 - val_sparse_categorical_accuracy: 0.5185
#
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 12/60
# 297/297 [==============================] - 79s 264ms/step - loss: 0.4872 - sparse_categorical_accuracy: 0.8043 - val_loss: 1.6081 - val_sparse_categorical_accuracy: 0.5215
#
# Epoch 00012: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 13/60
# 297/297 [==============================] - 81s 271ms/step - loss: 0.4344 - sparse_categorical_accuracy: 0.8269 - val_loss: 1.7311 - val_sparse_categorical_accuracy: 0.5276
#
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 14/60
# 297/297 [==============================] - 80s 268ms/step - loss: 0.4147 - sparse_categorical_accuracy: 0.8371 - val_loss: 1.7038 - val_sparse_categorical_accuracy: 0.5294
#
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 15/60
# 297/297 [==============================] - 80s 268ms/step - loss: 0.3678 - sparse_categorical_accuracy: 0.8544 - val_loss: 1.7544 - val_sparse_categorical_accuracy: 0.5167
#
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 16/60
# 297/297 [==============================] - 82s 275ms/step - loss: 0.3156 - sparse_categorical_accuracy: 0.8775 - val_loss: 2.0671 - val_sparse_categorical_accuracy: 0.5104
#
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 17/60
# 297/297 [==============================] - 82s 277ms/step - loss: 0.3179 - sparse_categorical_accuracy: 0.8757 - val_loss: 1.8863 - val_sparse_categorical_accuracy: 0.5176
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 18/60
# 297/297 [==============================] - 86s 288ms/step - loss: 0.2761 - sparse_categorical_accuracy: 0.8942 - val_loss: 2.3249 - val_sparse_categorical_accuracy: 0.5221
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 19/60
# 297/297 [==============================] - 74s 250ms/step - loss: 0.2980 - sparse_categorical_accuracy: 0.8863 - val_loss: 2.0797 - val_sparse_categorical_accuracy: 0.5255
#
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 20/60
# 297/297 [==============================] - 78s 263ms/step - loss: 0.2365 - sparse_categorical_accuracy: 0.9095 - val_loss: 2.4062 - val_sparse_categorical_accuracy: 0.5125
#
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 21/60
# 297/297 [==============================] - 81s 273ms/step - loss: 0.2445 - sparse_categorical_accuracy: 0.9056 - val_loss: 2.3419 - val_sparse_categorical_accuracy: 0.5333
#
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 22/60
# 297/297 [==============================] - 82s 275ms/step - loss: 0.2206 - sparse_categorical_accuracy: 0.9141 - val_loss: 2.4379 - val_sparse_categorical_accuracy: 0.5158
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 23/60
# 297/297 [==============================] - 77s 259ms/step - loss: 0.2219 - sparse_categorical_accuracy: 0.9162 - val_loss: 2.6209 - val_sparse_categorical_accuracy: 0.5140
#
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 24/60
# 297/297 [==============================] - 82s 277ms/step - loss: 0.2345 - sparse_categorical_accuracy: 0.9123 - val_loss: 2.7479 - val_sparse_categorical_accuracy: 0.5158
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 25/60
# 297/297 [==============================] - 80s 268ms/step - loss: 0.2285 - sparse_categorical_accuracy: 0.9143 - val_loss: 2.8448 - val_sparse_categorical_accuracy: 0.5255
#
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 26/60
# 297/297 [==============================] - 77s 258ms/step - loss: 0.2036 - sparse_categorical_accuracy: 0.9254 - val_loss: 2.6882 - val_sparse_categorical_accuracy: 0.5188
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 27/60
# 297/297 [==============================] - 76s 255ms/step - loss: 0.1901 - sparse_categorical_accuracy: 0.9300 - val_loss: 2.6070 - val_sparse_categorical_accuracy: 0.5113
#
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 28/60
# 297/297 [==============================] - 78s 262ms/step - loss: 0.1510 - sparse_categorical_accuracy: 0.9452 - val_loss: 3.0824 - val_sparse_categorical_accuracy: 0.5062
#
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 29/60
# 297/297 [==============================] - 79s 267ms/step - loss: 0.1774 - sparse_categorical_accuracy: 0.9347 - val_loss: 2.5925 - val_sparse_categorical_accuracy: 0.5237
#
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 30/60
# 297/297 [==============================] - 82s 274ms/step - loss: 0.1534 - sparse_categorical_accuracy: 0.9446 - val_loss: 2.9224 - val_sparse_categorical_accuracy: 0.5206
#
# Epoch 00030: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 31/60
# 297/297 [==============================] - 78s 264ms/step - loss: 0.1576 - sparse_categorical_accuracy: 0.9434 - val_loss: 3.2862 - val_sparse_categorical_accuracy: 0.5161
#
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 32/60
# 297/297 [==============================] - 83s 280ms/step - loss: 0.1438 - sparse_categorical_accuracy: 0.9470 - val_loss: 3.2131 - val_sparse_categorical_accuracy: 0.5255
#
# Epoch 00032: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 33/60
# 297/297 [==============================] - 76s 256ms/step - loss: 0.1411 - sparse_categorical_accuracy: 0.9494 - val_loss: 3.3372 - val_sparse_categorical_accuracy: 0.5215
#
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 34/60
# 297/297 [==============================] - 76s 254ms/step - loss: 0.1459 - sparse_categorical_accuracy: 0.9480 - val_loss: 3.0435 - val_sparse_categorical_accuracy: 0.5152
#
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 35/60
# 297/297 [==============================] - 72s 243ms/step - loss: 0.1216 - sparse_categorical_accuracy: 0.9563 - val_loss: 3.2519 - val_sparse_categorical_accuracy: 0.5092
#
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 36/60
# 297/297 [==============================] - 79s 264ms/step - loss: 0.1286 - sparse_categorical_accuracy: 0.9534 - val_loss: 3.2714 - val_sparse_categorical_accuracy: 0.5110
#
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 37/60
# 297/297 [==============================] - 80s 268ms/step - loss: 0.1686 - sparse_categorical_accuracy: 0.9395 - val_loss: 2.7057 - val_sparse_categorical_accuracy: 0.5179
#
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 38/60
# 297/297 [==============================] - 80s 268ms/step - loss: 0.1140 - sparse_categorical_accuracy: 0.9600 - val_loss: 3.3476 - val_sparse_categorical_accuracy: 0.5149
#
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 39/60
# 297/297 [==============================] - 78s 261ms/step - loss: 0.1024 - sparse_categorical_accuracy: 0.9636 - val_loss: 3.3557 - val_sparse_categorical_accuracy: 0.5173
#
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 40/60
# 297/297 [==============================] - 93s 314ms/step - loss: 0.1330 - sparse_categorical_accuracy: 0.9541 - val_loss: 2.6195 - val_sparse_categorical_accuracy: 0.5134
#
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 41/60
# 297/297 [==============================] - 84s 282ms/step - loss: 0.1053 - sparse_categorical_accuracy: 0.9644 - val_loss: 3.2150 - val_sparse_categorical_accuracy: 0.5113
#
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 42/60
# 297/297 [==============================] - 77s 258ms/step - loss: 0.1285 - sparse_categorical_accuracy: 0.9548 - val_loss: 3.2661 - val_sparse_categorical_accuracy: 0.5113
#
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 43/60
# 297/297 [==============================] - 73s 246ms/step - loss: 0.1364 - sparse_categorical_accuracy: 0.9551 - val_loss: 3.0654 - val_sparse_categorical_accuracy: 0.5273
#
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 44/60
# 297/297 [==============================] - 79s 267ms/step - loss: 0.1000 - sparse_categorical_accuracy: 0.9638 - val_loss: 3.4750 - val_sparse_categorical_accuracy: 0.5110
#
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 45/60
# 297/297 [==============================] - 80s 269ms/step - loss: 0.1026 - sparse_categorical_accuracy: 0.9641 - val_loss: 3.5418 - val_sparse_categorical_accuracy: 0.5104
#
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 46/60
# 297/297 [==============================] - 80s 271ms/step - loss: 0.1198 - sparse_categorical_accuracy: 0.9607 - val_loss: 3.2475 - val_sparse_categorical_accuracy: 0.5116
#
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 47/60
# 297/297 [==============================] - 78s 261ms/step - loss: 0.1264 - sparse_categorical_accuracy: 0.9549 - val_loss: 3.6568 - val_sparse_categorical_accuracy: 0.5182
#
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 48/60
# 297/297 [==============================] - 83s 279ms/step - loss: 0.1027 - sparse_categorical_accuracy: 0.9640 - val_loss: 3.7492 - val_sparse_categorical_accuracy: 0.4920
#
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 49/60
# 297/297 [==============================] - 80s 270ms/step - loss: 0.0955 - sparse_categorical_accuracy: 0.9659 - val_loss: 3.4074 - val_sparse_categorical_accuracy: 0.5095
#
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 50/60
# 297/297 [==============================] - 124s 418ms/step - loss: 0.0872 - sparse_categorical_accuracy: 0.9696 - val_loss: 3.6821 - val_sparse_categorical_accuracy: 0.5047
#
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 51/60
# 297/297 [==============================] - 80s 266ms/step - loss: 0.1508 - sparse_categorical_accuracy: 0.9509 - val_loss: 3.1134 - val_sparse_categorical_accuracy: 0.5140
#
# Epoch 00051: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 52/60
# 297/297 [==============================] - 78s 262ms/step - loss: 0.0608 - sparse_categorical_accuracy: 0.9809 - val_loss: 3.4965 - val_sparse_categorical_accuracy: 0.5149
#
# Epoch 00052: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 53/60
# 297/297 [==============================] - 84s 282ms/step - loss: 0.0960 - sparse_categorical_accuracy: 0.9680 - val_loss: 3.3479 - val_sparse_categorical_accuracy: 0.5170
#
# Epoch 00053: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 54/60
# 297/297 [==============================] - 86s 289ms/step - loss: 0.0976 - sparse_categorical_accuracy: 0.9665 - val_loss: 3.3888 - val_sparse_categorical_accuracy: 0.5176
#
# Epoch 00054: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 55/60
# 297/297 [==============================] - 79s 265ms/step - loss: 0.1056 - sparse_categorical_accuracy: 0.9669 - val_loss: 3.1111 - val_sparse_categorical_accuracy: 0.5149
#
# Epoch 00055: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 56/60
# 297/297 [==============================] - 84s 284ms/step - loss: 0.0766 - sparse_categorical_accuracy: 0.9745 - val_loss: 3.4650 - val_sparse_categorical_accuracy: 0.5134
#
# Epoch 00056: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 57/60
# 297/297 [==============================] - 77s 258ms/step - loss: 0.0858 - sparse_categorical_accuracy: 0.9712 - val_loss: 3.4604 - val_sparse_categorical_accuracy: 0.5044
#
# Epoch 00057: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 58/60
# 297/297 [==============================] - 84s 284ms/step - loss: 0.0718 - sparse_categorical_accuracy: 0.9764 - val_loss: 3.5952 - val_sparse_categorical_accuracy: 0.5107
#
# Epoch 00058: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 59/60
# 297/297 [==============================] - 76s 255ms/step - loss: 0.0985 - sparse_categorical_accuracy: 0.9679 - val_loss: 3.6124 - val_sparse_categorical_accuracy: 0.5164
#
# Epoch 00059: val_sparse_categorical_accuracy did not improve from 0.55197
# Epoch 60/60
# 297/297 [==============================] - 77s 260ms/step - loss: 0.0685 - sparse_categorical_accuracy: 0.9754 - val_loss: 3.7264 - val_sparse_categorical_accuracy: 0.5119
#
# Epoch 00060: val_sparse_categorical_accuracy did not improve from 0.55197

# %% [markdown]
# ### Plot Training and Validation Loss

# %%
# print keys 
history.history.keys()
# Out:
# dict_keys(['loss', 'sparse_categorical_accuracy', 'val_loss', 'val_sparse_categorical_accuracy'])

# %%
NR_EPOCHS = len(history.history['loss'])
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(NR_EPOCHS)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
accuracy_train = history.history['sparse_categorical_accuracy']
accuracy_val = history.history['val_sparse_categorical_accuracy']
epochs = range(NR_EPOCHS)
plt.plot(epochs, accuracy_train, 'g', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Load model and validate

# %%
model_age = load_model("./models/age_best_model.h5")
loss, acc = model_age.evaluate(test_generator)
print (loss, acc)
# Out:
# 23/23 [==============================] - 5s 215ms/step - loss: 1.0593 - sparse_categorical_accuracy: 0.5580
# 1.0592644214630127 0.5579761266708374

# %% [markdown]
# ### Show sample results

# %%
def show_faces(images, age=None, pred_age=None):
    plt.figure(figsize=(10,10))
    labels = {"Age": [pred_age, age]}
    for i in range(16):
        plt.subplot(4,4, i+1)
        plt.axis('off')
        #plt.xticks([])
        #plt.yticks([])
        #plt.grid(False)
        plt.imshow(images[i])
        
        if pred_age[i] is None:
            continue
           
            
        real_age = int(age[i])
        predicted_age = np.argmax(predicted[i])
                
                
        plt.title(f"Age Class: {age_dict[real_age]}\n Predicted Age Class: {age_dict[predicted_age]}", fontsize=8)
            
        plt.subplots_adjust(wspace=0.3)

sample_validation_images, sample_validation_labels = next(test_generator)
predicted = model_age.predict(sample_validation_images)
show_faces(sample_validation_images, age=sample_validation_labels, pred_age=predicted)

# %%
def predictor(filename) :
    test_image = filename
    image_result = Image.open(test_image)
    # test_image = image.load_img(test_image, target_size=(100,100))
    test_image = image.load_img(test_image, target_size=(224,224,3))
    test_image = image.img_to_array(test_image)
    test_image = test_image/255
    test_image = np.expand_dims(test_image, axis=0)
    result = model_age.predict(test_image)
    r = np.max(result)
    per = r*100
    percentage = round(per,4)
    categories = ['0-20','20-25','25-30','30-40','40-60','60+']
    image_result = plt.imshow(image_result)
    output = categories[np.argmax(result)]
    output = np.argmax(result)

    return result,percentage,output
EMOTION_DETECTOR = predictor('/kaggle/input/utkface-new/UTKFace/10_0_0_20170110221811823.jpg.chip.jpg')
print(EMOTION_DETECTOR)
# Out:
# (array([[9.9992585e-01, 7.1497663e-05, 2.3221669e-06, 2.2358793e-07,
#         9.7841493e-08, 5.7490517e-08]], dtype=float32), 99.9926, 0)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
sample_validation_images, sample_validation_labels = next(test_generator)
predict_x=model_age.predict(sample_validation_images) 
results=np.argmax(predict_x,axis=1)
cm = confusion_matrix(sample_validation_labels, results)
cm_plot_labels = ['0-20','20-25','25-30','30-40','40-60','60+']

cm_df = pd.DataFrame(cm, index = cm_plot_labels,
                     columns = cm_plot_labels
                    )
final_cm = cm_df
plt.figure(figsize = (5,5))
sns.heatmap(final_cm, annot = True,cmap='Greys',cbar=False,linewidth=2,fmt='d')
plt.title('CNN Emotion Classify UTK-AGE-VGG16')
plt.ylabel('True class')
plt.xlabel('Prediction class')
plt.show()

# %%
print('\t\tClassification Report For UTK-AGE-VGG16\n', classification_report(sample_validation_labels, results,target_names=cm_plot_labels))
# Out:
# 		Classification Report For UTK-AGE-VGG16
#                precision    recall  f1-score   support
#
#         0-20       0.75      0.75      0.75        12
#        20-25       0.00      0.00      0.00         7
#        25-30       0.47      0.67      0.55        12
#        30-40       0.46      0.43      0.44        14
#        40-60       0.71      0.77      0.74        13
#          60+       0.75      1.00      0.86         6
#
#     accuracy                           0.61        64
#    macro avg       0.52      0.60      0.56        64
# weighted avg       0.55      0.61      0.57        64
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /opt/conda/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
import sys

sys.version
# Out:
# '3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53) \n[GCC 9.4.0]'
