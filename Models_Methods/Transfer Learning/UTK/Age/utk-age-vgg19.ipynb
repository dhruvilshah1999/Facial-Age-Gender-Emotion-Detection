# %% [markdown]
# # Age Estimation using VGG19

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from tensorflow.keras.models import load_model
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
# from tf.keras.applications.vgg19.VGG19

from collections import Counter
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.utils import shuffle

import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm.notebook import tqdm

# %matplotlib inline

from PIL import Image
import shutil

# %% [markdown]
# ## Age estimation in age groups

# %% [markdown]
# ### Set image size and variables

# %%
IMAGE_SIZE = [224,224]
TRAIN_TEST_SPLIT = 0.3
BASE_DIR = '../input/utkface-new/UTKFace/'
NR_EPOCHS = 60

# %% [markdown]
# ### Define methods map direct age to classes

# %%
def age_to_class( age ):
    age_class = None
    if 0 <= age <= 20:
        age_class = 0
    if 20 < age <= 25:
        age_class = 1
    if 25 < age <= 30:
        age_class = 2
    if 30 < age <= 40:
        age_class = 3
    if 40 < age <= 60:
        age_class = 4
    if age > 60:
        age_class = 5
    return age_class

age_dict = {0:'0-20', 1:'20-25',2:'25-30', 3:'30-40', 4:'40-60', 5:'60+'}

def decode_age_label(age_id):
    return age_dict[int(age_id)]

# %% [markdown]
# ### Read input dataset

# %%
# read labels of image age, gender
image_paths = []
age_labels = []
gender_labels =[]
age_class = []

for filename in tqdm(os.listdir(BASE_DIR)):
  #read image path
  image_path = os.path.join(BASE_DIR, filename)
  #split filename to extract labels
  temp= filename.split('_')
  age = int(temp[0])
  gender = int(temp[1])
  image_paths.append(image_path)
  age_labels.append(age)
  gender_labels.append(gender)
  age_class.append(age_to_class(age))

# extract name of file 
names = []
for path in image_paths:
  temp = path.split('/')
  names.append(temp[4])

#convert to dataframe
df = pd.DataFrame()
df['image'], df['age'], df['gender'], df['age_class'], df['name'] = image_paths, age_labels, gender_labels, age_class, names
df.head()
df

# get and print the number of images in dataframe
age_verbose = [age_dict[int(age)] for age in df['age_class']]

print(Counter(age_verbose))
# Out:
#   0%|          | 0/23708 [00:00<?, ?it/s]
# Counter({'25-30': 5024, '0-20': 4877, '30-40': 4339, '40-60': 4311, '20-25': 2760, '60+': 2397})

# %% [markdown]
# ### Shuffle dataset

# %%
# shuffle dataset 
df = shuffle(df)

# %%
# check dataframe
df
# Out:
#                                                    image  age  gender  \
# 12099  ../input/utkface-new/UTKFace/36_0_3_2017011602...   36       0
# 5093   ../input/utkface-new/UTKFace/24_0_0_2017011621...   24       0
# 15758  ../input/utkface-new/UTKFace/25_1_4_2016122321...   25       1
# 21834  ../input/utkface-new/UTKFace/24_1_0_2017011719...   24       1
# 5596   ../input/utkface-new/UTKFace/40_0_0_2017010420...   40       0
# ...                                                  ...  ...     ...
# 15214  ../input/utkface-new/UTKFace/39_1_2_2017011619...   39       1
# 15889  ../input/utkface-new/UTKFace/4_1_0_20170109192...    4       1
# 11024  ../input/utkface-new/UTKFace/26_0_3_2017011918...   26       0
# 836    ../input/utkface-new/UTKFace/20_1_2_2017011616...   20       1
# 20934  ../input/utkface-new/UTKFace/55_0_3_2017011715...   55       0
#
#        age_class                                   name
# 12099          3  36_0_3_20170116024311670.jpg.chip.jpg
# 5093           1  24_0_0_20170116215529092.jpg.chip.jpg
# 15758          1  25_1_4_20161223214751864.jpg.chip.jpg
# 21834          1  24_1_0_20170117194955099.jpg.chip.jpg
# 5596           3  40_0_0_20170104205324669.jpg.chip.jpg
# ...          ...                                    ...
# 15214          3  39_1_2_20170116192459890.jpg.chip.jpg
# 15889          0   4_1_0_20170109192357612.jpg.chip.jpg
# 11024          2  26_0_3_20170119184306855.jpg.chip.jpg
# 836            0  20_1_2_20170116163810477.jpg.chip.jpg
# 20934          4  55_0_3_20170117153822293.jpg.chip.jpg
#
# [23708 rows x 5 columns]

# %% [markdown]
# ### Split Dataset into validation and test set

# %%
training_data = df.sample(frac=0.8, random_state=25)
temp = df.drop(training_data.index)


val_data =  temp.sample(frac=0.7, random_state=25)
testing_data = temp.drop(val_data.index)

 
print(f"No. of training examples: {training_data.shape[0]}")
print(f"No. of training examples: {val_data.shape[0]}")
print(f"No. of testing examples: {testing_data.shape[0]}")
# Out:
# No. of training examples: 18966
# No. of training examples: 3319
# No. of testing examples: 1423

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(rescale=1./255,
                               preprocessing_function=preprocess_input)

val_datagen = ImageDataGenerator(rescale=1./255,
                                preprocessing_function=preprocess_input)


CLASS_MODE = 'raw'
BATCH_SIZE = 64
BASE_DIR = '../input/utkface-new/UTKFace'

train_generator = train_datagen.flow_from_dataframe(dataframe=training_data, 
                                                directory=BASE_DIR, 
                                                x_col='name', 
                                                y_col='age_class', 
                                                class_mode=CLASS_MODE,
                                                batch_size=BATCH_SIZE, 
                                                shuffle=True, 
                                                target_size=IMAGE_SIZE)



val_generator = val_datagen.flow_from_dataframe(dataframe=val_data, 
                                              directory=BASE_DIR, 
                                              x_col='name', 
                                              y_col='age_class', 
                                              class_mode=CLASS_MODE, 
                                              batch_size=BATCH_SIZE,
                                              shuffle=False, 
                                              target_size=IMAGE_SIZE)

test_generator = val_datagen.flow_from_dataframe(dataframe=testing_data, 
                                              directory=BASE_DIR, 
                                              x_col='name', 
                                              y_col='age_class', 
                                              class_mode=CLASS_MODE, 
                                              batch_size=BATCH_SIZE,
                                              shuffle=False, 
                                              target_size=IMAGE_SIZE)
# Out:
# Found 18966 validated image filenames.
# Found 3319 validated image filenames.
# Found 1423 validated image filenames.

# %%
from pathlib import Path
path = Path("./models")
path.mkdir(exist_ok=True)


MODEL_PATH = "./models/age_best_model.h5"


checkpoint = tf.keras.callbacks.ModelCheckpoint(MODEL_PATH, 
                                                monitor='val_sparse_categorical_accuracy', 
                                                verbose=1, 
                                                save_best_only=True, 
                                                mode='max')

import datetime
log_dir = '../tblogs/age_model_' + datetime.datetime.now().strftime('%y-%m-%d_%H-%M')
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=0)
# Out:
# 2022-12-14 20:48:57.461352: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-12-14 20:48:57.461394: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-12-14 20:48:57.524425: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1614] Profiler found 1 GPUs
# 2022-12-14 20:48:57.557249: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-12-14 20:48:57.557423: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed

# %% [markdown]
# ### Build and load Model

# %%
# # detect and init the TPU
# tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()

# # instantiate a distribution strategy
# tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

# %%
# load VGG19 without the last 3 Dense layers, in order to train these new
from tensorflow.keras.models import *

vgg = VGG19(input_shape = IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# 2022-12-14 20:48:57.725103: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:48:57.840088: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:48:57.840895: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:48:57.841847: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-14 20:48:57.842171: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:48:57.842867: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:48:57.843512: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:49:00.153295: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:49:00.154108: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:49:00.154825: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 20:49:00.155453: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 3s 0us/step
# 80150528/80134624 [==============================] - 3s 0us/step

# %%
from keras.layers import *
for layer in vgg.layers:
  layer.trainable = False


x = Flatten()(vgg.output)
x = Dense(4096, activation='relu')(x)
x = Dense(4096, activation='relu')(x)
# x = Dropout(0.5)(x)
prediction = Dense(6, activation='softmax')(x)
model = Model(inputs=vgg.input, outputs=prediction)
    
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 24582
# =================================================================
# Total params: 139,594,822
# Trainable params: 119,570,438
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
from keras import callbacks

earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 5, 
                                        restore_best_weights = True)

history = model.fit(train_generator,
                    epochs=NR_EPOCHS,
                    validation_data=val_generator,
                    callbacks = [tensorboard_callback, checkpoint]
                    )
# Out:
# 2022-12-14 20:49:04.324111: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/60
# 2022-12-14 20:49:06.256353: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
#   1/297 [..............................] - ETA: 59:34 - loss: 1.9525 - sparse_categorical_accuracy: 0.2031
# 2022-12-14 20:49:16.455063: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-12-14 20:49:16.455110: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
#   2/297 [..............................] - ETA: 2:35 - loss: 34.6231 - sparse_categorical_accuracy: 0.1953
# 2022-12-14 20:49:16.962593: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-12-14 20:49:16.963096: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed
# 2022-12-14 20:49:17.102211: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:673]  GpuTracer has collected 160 callback api events and 157 activity events.
# 2022-12-14 20:49:17.109525: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-12-14 20:49:17.123958: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ../tblogs/age_model_22-12-14_20-48/train/plugins/profile/2022_12_14_20_49_17
#
# 2022-12-14 20:49:17.129085: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to ../tblogs/age_model_22-12-14_20-48/train/plugins/profile/2022_12_14_20_49_17/ce5060378b97.trace.json.gz
# 2022-12-14 20:49:17.149185: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ../tblogs/age_model_22-12-14_20-48/train/plugins/profile/2022_12_14_20_49_17
#
# 2022-12-14 20:49:17.151113: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to ../tblogs/age_model_22-12-14_20-48/train/plugins/profile/2022_12_14_20_49_17/ce5060378b97.memory_profile.json.gz
# 2022-12-14 20:49:17.152059: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: ../tblogs/age_model_22-12-14_20-48/train/plugins/profile/2022_12_14_20_49_17
# Dumped tool data for xplane.pb to ../tblogs/age_model_22-12-14_20-48/train/plugins/profile/2022_12_14_20_49_17/ce5060378b97.xplane.pb
# Dumped tool data for overview_page.pb to ../tblogs/age_model_22-12-14_20-48/train/plugins/profile/2022_12_14_20_49_17/ce5060378b97.overview_page.pb
# Dumped tool data for input_pipeline.pb to ../tblogs/age_model_22-12-14_20-48/train/plugins/profile/2022_12_14_20_49_17/ce5060378b97.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to ../tblogs/age_model_22-12-14_20-48/train/plugins/profile/2022_12_14_20_49_17/ce5060378b97.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to ../tblogs/age_model_22-12-14_20-48/train/plugins/profile/2022_12_14_20_49_17/ce5060378b97.kernel_stats.pb
# 297/297 [==============================] - 171s 537ms/step - loss: 2.1991 - sparse_categorical_accuracy: 0.4381 - val_loss: 1.1753 - val_sparse_categorical_accuracy: 0.4914
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.49141, saving model to ./models/age_best_model.h5
# Epoch 2/60
# 297/297 [==============================] - 88s 297ms/step - loss: 1.1215 - sparse_categorical_accuracy: 0.5217 - val_loss: 1.1647 - val_sparse_categorical_accuracy: 0.5011
#
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.49141 to 0.50105, saving model to ./models/age_best_model.h5
# Epoch 3/60
# 297/297 [==============================] - 88s 295ms/step - loss: 1.0508 - sparse_categorical_accuracy: 0.5476 - val_loss: 1.1854 - val_sparse_categorical_accuracy: 0.4965
#
# Epoch 00003: val_sparse_categorical_accuracy did not improve from 0.50105
# Epoch 4/60
# 297/297 [==============================] - 95s 319ms/step - loss: 1.0012 - sparse_categorical_accuracy: 0.5673 - val_loss: 1.2170 - val_sparse_categorical_accuracy: 0.4905
#
# Epoch 00004: val_sparse_categorical_accuracy did not improve from 0.50105
# Epoch 5/60
# 297/297 [==============================] - 86s 288ms/step - loss: 0.9537 - sparse_categorical_accuracy: 0.5935 - val_loss: 1.1732 - val_sparse_categorical_accuracy: 0.5182
#
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.50105 to 0.51823, saving model to ./models/age_best_model.h5
# Epoch 6/60
# 297/297 [==============================] - 86s 290ms/step - loss: 0.9094 - sparse_categorical_accuracy: 0.6160 - val_loss: 1.1146 - val_sparse_categorical_accuracy: 0.5402
#
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.51823 to 0.54022, saving model to ./models/age_best_model.h5
# Epoch 7/60
# 297/297 [==============================] - 86s 291ms/step - loss: 0.8859 - sparse_categorical_accuracy: 0.6191 - val_loss: 1.2170 - val_sparse_categorical_accuracy: 0.5011
#
# Epoch 00007: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 8/60
# 297/297 [==============================] - 85s 285ms/step - loss: 0.8568 - sparse_categorical_accuracy: 0.6321 - val_loss: 1.2737 - val_sparse_categorical_accuracy: 0.5011
#
# Epoch 00008: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 9/60
# 297/297 [==============================] - 85s 288ms/step - loss: 0.8332 - sparse_categorical_accuracy: 0.6460 - val_loss: 1.1726 - val_sparse_categorical_accuracy: 0.5348
#
# Epoch 00009: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 10/60
# 297/297 [==============================] - 89s 300ms/step - loss: 0.8033 - sparse_categorical_accuracy: 0.6569 - val_loss: 1.1828 - val_sparse_categorical_accuracy: 0.5369
#
# Epoch 00010: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 11/60
# 297/297 [==============================] - 73s 244ms/step - loss: 0.7517 - sparse_categorical_accuracy: 0.6887 - val_loss: 1.2286 - val_sparse_categorical_accuracy: 0.5261
#
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 12/60
# 297/297 [==============================] - 83s 280ms/step - loss: 0.7149 - sparse_categorical_accuracy: 0.7046 - val_loss: 1.2895 - val_sparse_categorical_accuracy: 0.5267
#
# Epoch 00012: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 13/60
# 297/297 [==============================] - 83s 279ms/step - loss: 0.6955 - sparse_categorical_accuracy: 0.7125 - val_loss: 1.3528 - val_sparse_categorical_accuracy: 0.5212
#
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 14/60
# 297/297 [==============================] - 85s 287ms/step - loss: 0.6501 - sparse_categorical_accuracy: 0.7315 - val_loss: 1.4677 - val_sparse_categorical_accuracy: 0.5282
#
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 15/60
# 297/297 [==============================] - 82s 275ms/step - loss: 0.6384 - sparse_categorical_accuracy: 0.7419 - val_loss: 1.5086 - val_sparse_categorical_accuracy: 0.5324
#
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 16/60
# 297/297 [==============================] - 78s 263ms/step - loss: 0.6117 - sparse_categorical_accuracy: 0.7511 - val_loss: 1.4191 - val_sparse_categorical_accuracy: 0.5050
#
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 17/60
# 297/297 [==============================] - 84s 284ms/step - loss: 0.6093 - sparse_categorical_accuracy: 0.7561 - val_loss: 1.4938 - val_sparse_categorical_accuracy: 0.5258
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 18/60
# 297/297 [==============================] - 81s 274ms/step - loss: 0.5541 - sparse_categorical_accuracy: 0.7788 - val_loss: 1.6402 - val_sparse_categorical_accuracy: 0.5059
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 19/60
# 297/297 [==============================] - 72s 242ms/step - loss: 0.5671 - sparse_categorical_accuracy: 0.7730 - val_loss: 1.7618 - val_sparse_categorical_accuracy: 0.4667
#
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 20/60
# 297/297 [==============================] - 82s 276ms/step - loss: 0.5341 - sparse_categorical_accuracy: 0.7871 - val_loss: 1.7057 - val_sparse_categorical_accuracy: 0.5098
#
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 21/60
# 297/297 [==============================] - 82s 275ms/step - loss: 0.4656 - sparse_categorical_accuracy: 0.8178 - val_loss: 1.9250 - val_sparse_categorical_accuracy: 0.5155
#
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 22/60
# 297/297 [==============================] - 84s 281ms/step - loss: 0.4531 - sparse_categorical_accuracy: 0.8240 - val_loss: 1.8848 - val_sparse_categorical_accuracy: 0.5161
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 23/60
# 297/297 [==============================] - 79s 265ms/step - loss: 0.4357 - sparse_categorical_accuracy: 0.8329 - val_loss: 2.0834 - val_sparse_categorical_accuracy: 0.5140
#
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 24/60
# 297/297 [==============================] - 81s 273ms/step - loss: 0.4349 - sparse_categorical_accuracy: 0.8314 - val_loss: 1.8021 - val_sparse_categorical_accuracy: 0.5146
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 25/60
# 297/297 [==============================] - 87s 293ms/step - loss: 0.3873 - sparse_categorical_accuracy: 0.8525 - val_loss: 2.2966 - val_sparse_categorical_accuracy: 0.5056
#
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 26/60
# 297/297 [==============================] - 79s 265ms/step - loss: 0.4030 - sparse_categorical_accuracy: 0.8441 - val_loss: 1.9594 - val_sparse_categorical_accuracy: 0.5071
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 27/60
# 297/297 [==============================] - 71s 240ms/step - loss: 0.3920 - sparse_categorical_accuracy: 0.8505 - val_loss: 1.9741 - val_sparse_categorical_accuracy: 0.5194
#
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 28/60
# 297/297 [==============================] - 81s 272ms/step - loss: 0.3700 - sparse_categorical_accuracy: 0.8569 - val_loss: 2.2231 - val_sparse_categorical_accuracy: 0.5077
#
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 29/60
# 297/297 [==============================] - 81s 271ms/step - loss: 0.3566 - sparse_categorical_accuracy: 0.8645 - val_loss: 2.1044 - val_sparse_categorical_accuracy: 0.4947
#
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 30/60
# 297/297 [==============================] - 83s 280ms/step - loss: 0.4285 - sparse_categorical_accuracy: 0.8368 - val_loss: 2.2592 - val_sparse_categorical_accuracy: 0.5098
#
# Epoch 00030: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 31/60
# 297/297 [==============================] - 78s 262ms/step - loss: 0.3516 - sparse_categorical_accuracy: 0.8679 - val_loss: 2.2508 - val_sparse_categorical_accuracy: 0.5095
#
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 32/60
# 297/297 [==============================] - 81s 272ms/step - loss: 0.3062 - sparse_categorical_accuracy: 0.8808 - val_loss: 2.5174 - val_sparse_categorical_accuracy: 0.5104
#
# Epoch 00032: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 33/60
# 297/297 [==============================] - 82s 276ms/step - loss: 0.3313 - sparse_categorical_accuracy: 0.8724 - val_loss: 2.4697 - val_sparse_categorical_accuracy: 0.5014
#
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 34/60
# 297/297 [==============================] - 77s 259ms/step - loss: 0.3045 - sparse_categorical_accuracy: 0.8836 - val_loss: 2.9221 - val_sparse_categorical_accuracy: 0.4896
#
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 35/60
# 297/297 [==============================] - 79s 265ms/step - loss: 0.2912 - sparse_categorical_accuracy: 0.8901 - val_loss: 2.6886 - val_sparse_categorical_accuracy: 0.5065
#
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 36/60
# 297/297 [==============================] - 77s 258ms/step - loss: 0.2994 - sparse_categorical_accuracy: 0.8860 - val_loss: 2.8962 - val_sparse_categorical_accuracy: 0.5104
#
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 37/60
# 297/297 [==============================] - 81s 274ms/step - loss: 0.2639 - sparse_categorical_accuracy: 0.9021 - val_loss: 2.6410 - val_sparse_categorical_accuracy: 0.5050
#
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 38/60
# 297/297 [==============================] - 76s 257ms/step - loss: 0.2682 - sparse_categorical_accuracy: 0.9001 - val_loss: 2.7611 - val_sparse_categorical_accuracy: 0.5005
#
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 39/60
# 297/297 [==============================] - 92s 310ms/step - loss: 0.2588 - sparse_categorical_accuracy: 0.9019 - val_loss: 2.7048 - val_sparse_categorical_accuracy: 0.5089
#
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 40/60
# 297/297 [==============================] - 82s 276ms/step - loss: 0.2681 - sparse_categorical_accuracy: 0.8980 - val_loss: 2.9409 - val_sparse_categorical_accuracy: 0.5053
#
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 41/60
# 297/297 [==============================] - 84s 282ms/step - loss: 0.2354 - sparse_categorical_accuracy: 0.9108 - val_loss: 3.0225 - val_sparse_categorical_accuracy: 0.4986
#
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 42/60
# 297/297 [==============================] - 81s 273ms/step - loss: 0.2675 - sparse_categorical_accuracy: 0.9016 - val_loss: 2.7956 - val_sparse_categorical_accuracy: 0.5113
#
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 43/60
# 297/297 [==============================] - 90s 304ms/step - loss: 0.2158 - sparse_categorical_accuracy: 0.9177 - val_loss: 2.8510 - val_sparse_categorical_accuracy: 0.5044
#
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 44/60
# 297/297 [==============================] - 81s 271ms/step - loss: 0.2701 - sparse_categorical_accuracy: 0.8999 - val_loss: 2.7732 - val_sparse_categorical_accuracy: 0.4995
#
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 45/60
# 297/297 [==============================] - 80s 268ms/step - loss: 0.2241 - sparse_categorical_accuracy: 0.9140 - val_loss: 2.8075 - val_sparse_categorical_accuracy: 0.5074
#
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 46/60
# 297/297 [==============================] - 73s 244ms/step - loss: 0.1829 - sparse_categorical_accuracy: 0.9336 - val_loss: 3.3863 - val_sparse_categorical_accuracy: 0.5044
#
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 47/60
# 297/297 [==============================] - 83s 278ms/step - loss: 0.2627 - sparse_categorical_accuracy: 0.8999 - val_loss: 3.1947 - val_sparse_categorical_accuracy: 0.4923
#
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 48/60
# 297/297 [==============================] - 82s 277ms/step - loss: 0.1889 - sparse_categorical_accuracy: 0.9271 - val_loss: 3.5895 - val_sparse_categorical_accuracy: 0.5029
#
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 49/60
# 297/297 [==============================] - 82s 275ms/step - loss: 0.2177 - sparse_categorical_accuracy: 0.9212 - val_loss: 3.1103 - val_sparse_categorical_accuracy: 0.4902
#
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 50/60
# 297/297 [==============================] - 82s 276ms/step - loss: 0.1990 - sparse_categorical_accuracy: 0.9252 - val_loss: 3.0314 - val_sparse_categorical_accuracy: 0.5038
#
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 51/60
# 297/297 [==============================] - 81s 273ms/step - loss: 0.2325 - sparse_categorical_accuracy: 0.9143 - val_loss: 2.6439 - val_sparse_categorical_accuracy: 0.5056
#
# Epoch 00051: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 52/60
# 297/297 [==============================] - 89s 299ms/step - loss: 0.1891 - sparse_categorical_accuracy: 0.9334 - val_loss: 3.5735 - val_sparse_categorical_accuracy: 0.4995
#
# Epoch 00052: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 53/60
# 297/297 [==============================] - 89s 300ms/step - loss: 0.1796 - sparse_categorical_accuracy: 0.9338 - val_loss: 3.2721 - val_sparse_categorical_accuracy: 0.5053
#
# Epoch 00053: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 54/60
# 297/297 [==============================] - 74s 247ms/step - loss: 0.2151 - sparse_categorical_accuracy: 0.9202 - val_loss: 3.1946 - val_sparse_categorical_accuracy: 0.5008
#
# Epoch 00054: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 55/60
# 297/297 [==============================] - 93s 312ms/step - loss: 0.1849 - sparse_categorical_accuracy: 0.9303 - val_loss: 3.5406 - val_sparse_categorical_accuracy: 0.4800
#
# Epoch 00055: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 56/60
# 297/297 [==============================] - 80s 269ms/step - loss: 0.1998 - sparse_categorical_accuracy: 0.9223 - val_loss: 3.3866 - val_sparse_categorical_accuracy: 0.4977
#
# Epoch 00056: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 57/60
# 297/297 [==============================] - 79s 266ms/step - loss: 0.1876 - sparse_categorical_accuracy: 0.9319 - val_loss: 3.1095 - val_sparse_categorical_accuracy: 0.4869
#
# Epoch 00057: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 58/60
# 297/297 [==============================] - 81s 272ms/step - loss: 0.1465 - sparse_categorical_accuracy: 0.9462 - val_loss: 3.6625 - val_sparse_categorical_accuracy: 0.5020
#
# Epoch 00058: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 59/60
# 297/297 [==============================] - 79s 265ms/step - loss: 0.1620 - sparse_categorical_accuracy: 0.9416 - val_loss: 3.5985 - val_sparse_categorical_accuracy: 0.4833
#
# Epoch 00059: val_sparse_categorical_accuracy did not improve from 0.54022
# Epoch 60/60
# 297/297 [==============================] - 81s 271ms/step - loss: 0.1744 - sparse_categorical_accuracy: 0.9368 - val_loss: 3.7248 - val_sparse_categorical_accuracy: 0.4971
#
# Epoch 00060: val_sparse_categorical_accuracy did not improve from 0.54022

# %% [markdown]
# ### Plot Training and Validation Loss

# %%
# print keys 
history.history.keys()
# Out:
# dict_keys(['loss', 'sparse_categorical_accuracy', 'val_loss', 'val_sparse_categorical_accuracy'])

# %%
NR_EPOCHS = len(history.history['loss'])
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(NR_EPOCHS)
plt.plot(epochs, loss_train, 'g', label='Training loss')
plt.plot(epochs, loss_val, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
accuracy_train = history.history['sparse_categorical_accuracy']
accuracy_val = history.history['val_sparse_categorical_accuracy']
epochs = range(NR_EPOCHS)
plt.plot(epochs, accuracy_train, 'g', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Load model and validate

# %%
model_age = load_model("./models/age_best_model.h5")
loss, acc = model_age.evaluate(test_generator)
print (loss, acc)
# Out:
# 23/23 [==============================] - 7s 277ms/step - loss: 1.0742 - sparse_categorical_accuracy: 0.5531
# 1.0741641521453857 0.5530568957328796

# %% [markdown]
# ### Show sample results

# %%
def show_faces(images, age=None, pred_age=None):
    plt.figure(figsize=(10,10))
    labels = {"Age": [pred_age, age]}
    for i in range(16):
        plt.subplot(4,4, i+1)
        plt.axis('off')
        #plt.xticks([])
        #plt.yticks([])
        #plt.grid(False)
        plt.imshow(images[i])
        
        if pred_age[i] is None:
            continue
           
            
        real_age = int(age[i])
        predicted_age = np.argmax(predicted[i])
                
                
        plt.title(f"Age Class: {age_dict[real_age]}\n Predicted Age Class: {age_dict[predicted_age]}", fontsize=8)
            
        plt.subplots_adjust(wspace=0.3)

sample_validation_images, sample_validation_labels = next(test_generator)
predicted = model_age.predict(sample_validation_images)
show_faces(sample_validation_images, age=sample_validation_labels, pred_age=predicted)

# %% [markdown]
# ## Direct Age Estimation

# %%
def predictor(filename) :
    test_image = filename
    image_result = Image.open(test_image)
    # test_image = image.load_img(test_image, target_size=(100,100))
    test_image = image.load_img(test_image, target_size=(224,224,3))
    test_image = image.img_to_array(test_image)
    test_image = test_image/255
    test_image = np.expand_dims(test_image, axis=0)
    result = model_age.predict(test_image)
    r = np.max(result)
    per = r*100
    percentage = round(per,4)
    categories = ['0-20','20-25','25-30','30-40','40-60','60+']
    image_result = plt.imshow(image_result)
    output = categories[np.argmax(result)]
    output = np.argmax(result)

    return result,percentage,output
EMOTION_DETECTOR = predictor('/kaggle/input/utkface-new/UTKFace/10_0_0_20170110221811823.jpg.chip.jpg')
print(EMOTION_DETECTOR)
# Out:
# (array([[9.9500632e-01, 4.1409498e-03, 8.2175160e-04, 2.8639239e-05,
#         1.9689667e-06, 3.7234884e-07]], dtype=float32), 99.5006, 0)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
sample_validation_images, sample_validation_labels = next(test_generator)
predict_x=model_age.predict(sample_validation_images) 
results=np.argmax(predict_x,axis=1)
cm = confusion_matrix(sample_validation_labels, results)
cm_plot_labels = ['0-20','20-25','25-30','30-40','40-60','60+']

cm_df = pd.DataFrame(cm, index = cm_plot_labels,
                     columns = cm_plot_labels
                    )
final_cm = cm_df
plt.figure(figsize = (5,5))
sns.heatmap(final_cm, annot = True,cmap='Greys',cbar=False,linewidth=2,fmt='d')
plt.title('CNN Emotion Classify UTK-AGE-VGG19')
plt.ylabel('True class')
plt.xlabel('Prediction class')
plt.show()

# %%
print('\t\tClassification Report For UTK-AGE-VGG19\n', classification_report(sample_validation_labels, results,target_names=cm_plot_labels))
# Out:
# 		Classification Report For UTK-AGE-VGG19
#                precision    recall  f1-score   support
#
#         0-20       1.00      0.92      0.96        13
#        20-25       0.67      0.40      0.50         5
#        25-30       0.62      0.62      0.62        16
#        30-40       0.11      0.14      0.12         7
#        40-60       0.57      0.62      0.59        13
#          60+       0.90      0.90      0.90        10
#
#     accuracy                           0.66        64
#    macro avg       0.65      0.60      0.62        64
# weighted avg       0.68      0.66      0.66        64

# %% [markdown]
# ### Load and build model

# %% [markdown]
# ### Plot Training and Validation Loss
