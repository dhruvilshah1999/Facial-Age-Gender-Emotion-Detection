# %% [markdown]
# # Age Estimation using VGG19

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.applications.vgg19 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from tensorflow.keras.models import load_model
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
# from tf.keras.applications.vgg19.VGG19

from collections import Counter
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.utils import shuffle

import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm.notebook import tqdm

# %matplotlib inline

from PIL import Image
import shutil

# %% [markdown]
# ## Age estimation in age groups

# %% [markdown]
# ### Set image size and variables

# %%
IMAGE_SIZE = [224,224]
TRAIN_TEST_SPLIT = 0.3
BASE_DIR = '../input/utkface-new/UTKFace/'
NR_EPOCHS = 60

# %% [markdown]
# ### Define methods map direct age to classes

# %%
def age_to_class( age ):
    age_class = None
    if 0 <= age <= 20:
        age_class = 0
    if 20 < age <= 25:
        age_class = 1
    if 25 < age <= 30:
        age_class = 2
    if 30 < age <= 40:
        age_class = 3
    if 40 < age <= 60:
        age_class = 4
    if age > 60:
        age_class = 5
    return age_class

age_dict = {0:'0-20', 1:'20-25',2:'25-30', 3:'30-40', 4:'40-60', 5:'60+'}

def decode_age_label(age_id):
    return age_dict[int(age_id)]

# %% [markdown]
# ### Read input dataset

# %%
# read labels of image age, gender
image_paths = []
age_labels = []
gender_labels =[]
age_class = []

for filename in tqdm(os.listdir(BASE_DIR)):
  #read image path
  image_path = os.path.join(BASE_DIR, filename)
  #split filename to extract labels
  temp= filename.split('_')
  age = int(temp[0])
  gender = int(temp[1])
  image_paths.append(image_path)
  age_labels.append(age)
  gender_labels.append(gender)
  age_class.append(age_to_class(age))

# extract name of file 
names = []
for path in image_paths:
  temp = path.split('/')
  names.append(temp[4])

#convert to dataframe
df = pd.DataFrame()
df['image'], df['age'], df['gender'], df['age_class'], df['name'] = image_paths, age_labels, gender_labels, age_class, names
df.head()
df

# get and print the number of images in dataframe
age_verbose = [age_dict[int(age)] for age in df['age_class']]

print(Counter(age_verbose))
# Out:
#   0%|          | 0/23708 [00:00<?, ?it/s]
# Counter({'25-30': 5024, '0-20': 4877, '30-40': 4339, '40-60': 4311, '20-25': 2760, '60+': 2397})

# %% [markdown]
# ### Shuffle dataset

# %%
# shuffle dataset 
df = shuffle(df)

# %%
# check dataframe
df
# Out:
#                                                    image  age  gender  \
# 4716   ../input/utkface-new/UTKFace/26_1_1_2017011615...   26       1
# 15650  ../input/utkface-new/UTKFace/40_0_0_2017011718...   40       0
# 1929   ../input/utkface-new/UTKFace/60_0_0_2017011120...   60       0
# 4737   ../input/utkface-new/UTKFace/30_0_2_2017011617...   30       0
# 1396   ../input/utkface-new/UTKFace/32_1_2_2017011619...   32       1
# ...                                                  ...  ...     ...
# 23086  ../input/utkface-new/UTKFace/21_1_2_2017011618...   21       1
# 20452  ../input/utkface-new/UTKFace/25_1_3_2017011714...   25       1
# 16647  ../input/utkface-new/UTKFace/36_1_0_2017010518...   36       1
# 1912   ../input/utkface-new/UTKFace/55_0_3_2017011917...   55       0
# 17998  ../input/utkface-new/UTKFace/43_0_2_2017011713...   43       0
#
#        age_class                                   name
# 4716           2  26_1_1_20170116155801198.jpg.chip.jpg
# 15650          3  40_0_0_20170117181229922.jpg.chip.jpg
# 1929           4  60_0_0_20170111202420384.jpg.chip.jpg
# 4737           2  30_0_2_20170116173731692.jpg.chip.jpg
# 1396           3  32_1_2_20170116190147549.jpg.chip.jpg
# ...          ...                                    ...
# 23086          1  21_1_2_20170116181138337.jpg.chip.jpg
# 20452          1  25_1_3_20170117143756281.jpg.chip.jpg
# 16647          3  36_1_0_20170105183405999.jpg.chip.jpg
# 1912           4  55_0_3_20170119171706159.jpg.chip.jpg
# 17998          4  43_0_2_20170117134842975.jpg.chip.jpg
#
# [23708 rows x 5 columns]

# %% [markdown]
# ### Split Dataset into validation and test set

# %%
training_data = df.sample(frac=0.8, random_state=25)
temp = df.drop(training_data.index)


val_data =  temp.sample(frac=0.7, random_state=25)
testing_data = temp.drop(val_data.index)

 
print(f"No. of training examples: {training_data.shape[0]}")
print(f"No. of training examples: {val_data.shape[0]}")
print(f"No. of testing examples: {testing_data.shape[0]}")
# Out:
# No. of training examples: 18966
# No. of training examples: 3319
# No. of testing examples: 1423

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(rescale=1./255,
                               preprocessing_function=preprocess_input)

val_datagen = ImageDataGenerator(rescale=1./255,
                                preprocessing_function=preprocess_input)


CLASS_MODE = 'raw'
BATCH_SIZE = 64
BASE_DIR = '../input/utkface-new/UTKFace'

train_generator = train_datagen.flow_from_dataframe(dataframe=training_data, 
                                                directory=BASE_DIR, 
                                                x_col='name', 
                                                y_col='gender', 
                                                class_mode=CLASS_MODE,
                                                batch_size=BATCH_SIZE, 
                                                shuffle=True, 
                                                target_size=IMAGE_SIZE)



val_generator = val_datagen.flow_from_dataframe(dataframe=val_data, 
                                              directory=BASE_DIR, 
                                              x_col='name', 
                                              y_col='gender', 
                                              class_mode=CLASS_MODE, 
                                              batch_size=BATCH_SIZE,
                                              shuffle=False, 
                                              target_size=IMAGE_SIZE)

test_generator = val_datagen.flow_from_dataframe(dataframe=testing_data, 
                                              directory=BASE_DIR, 
                                              x_col='name', 
                                              y_col='gender', 
                                              class_mode=CLASS_MODE, 
                                              batch_size=BATCH_SIZE,
                                              shuffle=False, 
                                              target_size=IMAGE_SIZE)
# Out:
# Found 18966 validated image filenames.
# Found 3319 validated image filenames.
# Found 1423 validated image filenames.

# %%
from pathlib import Path
path = Path("./models")
path.mkdir(exist_ok=True)


MODEL_PATH = "./models/age_best_model.h5"


checkpoint = tf.keras.callbacks.ModelCheckpoint(MODEL_PATH, 
                                                monitor='val_sparse_categorical_accuracy', 
                                                verbose=1, 
                                                save_best_only=True, 
                                                mode='max')

import datetime
log_dir = '../tblogs/age_model_' + datetime.datetime.now().strftime('%y-%m-%d_%H-%M')
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=0)
# Out:
# 2022-12-15 01:01:35.386329: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-12-15 01:01:35.386369: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-12-15 01:01:35.452532: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1614] Profiler found 1 GPUs
# 2022-12-15 01:01:35.491370: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-12-15 01:01:35.491592: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed

# %% [markdown]
# ### Build and load Model

# %%
# # detect and init the TPU
# tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()

# # instantiate a distribution strategy
# tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

# %%
# load VGG19 without the last 3 Dense layers, in order to train these new
from tensorflow.keras.models import *

vgg = VGG19(input_shape = IMAGE_SIZE + [3], weights='imagenet', include_top=False)
# Out:
# 2022-12-15 01:01:35.663124: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 01:01:35.758036: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 01:01:35.758994: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 01:01:35.760287: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-15 01:01:35.760676: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 01:01:35.761413: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 01:01:35.762106: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 01:01:37.875821: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 01:01:37.876747: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 01:01:37.877496: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-15 01:01:37.878153: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 4s 0us/step
# 80150528/80134624 [==============================] - 4s 0us/step

# %%
from keras.layers import *
for layer in vgg.layers:
  layer.trainable = False


x = Flatten()(vgg.output)
x = Dense(4096, activation='relu')(x)
x = Dense(4096, activation='relu')(x)
# x = Dropout(0.5)(x)
prediction = Dense(2, activation='softmax')(x)
model = Model(inputs=vgg.input, outputs=prediction)
    
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv4 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv4 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv4 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 8194
# =================================================================
# Total params: 139,578,434
# Trainable params: 119,554,050
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
from keras import callbacks

earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 5, 
                                        restore_best_weights = True)

history = model.fit(train_generator,
                    epochs=NR_EPOCHS,
                    validation_data=val_generator,
                    callbacks = [tensorboard_callback, checkpoint]
                    )
# Out:
# 2022-12-15 01:01:43.701863: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/60
# 2022-12-15 01:01:45.757601: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
#   1/297 [..............................] - ETA: 1:01:37 - loss: 0.6986 - sparse_categorical_accuracy: 0.4844
# 2022-12-15 01:01:56.251146: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-12-15 01:01:56.251190: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
#   2/297 [..............................] - ETA: 2:39 - loss: 74.8586 - sparse_categorical_accuracy: 0.4766
# 2022-12-15 01:01:56.770774: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-12-15 01:01:56.771601: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed
# 2022-12-15 01:01:56.916382: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:673]  GpuTracer has collected 160 callback api events and 157 activity events.
# 2022-12-15 01:01:56.924044: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-12-15 01:01:56.939167: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ../tblogs/age_model_22-12-15_01-01/train/plugins/profile/2022_12_15_01_01_56
#
# 2022-12-15 01:01:56.943792: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to ../tblogs/age_model_22-12-15_01-01/train/plugins/profile/2022_12_15_01_01_56/a2c97ce70c8d.trace.json.gz
# 2022-12-15 01:01:56.962852: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ../tblogs/age_model_22-12-15_01-01/train/plugins/profile/2022_12_15_01_01_56
#
# 2022-12-15 01:01:56.965485: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to ../tblogs/age_model_22-12-15_01-01/train/plugins/profile/2022_12_15_01_01_56/a2c97ce70c8d.memory_profile.json.gz
# 2022-12-15 01:01:56.966608: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: ../tblogs/age_model_22-12-15_01-01/train/plugins/profile/2022_12_15_01_01_56
# Dumped tool data for xplane.pb to ../tblogs/age_model_22-12-15_01-01/train/plugins/profile/2022_12_15_01_01_56/a2c97ce70c8d.xplane.pb
# Dumped tool data for overview_page.pb to ../tblogs/age_model_22-12-15_01-01/train/plugins/profile/2022_12_15_01_01_56/a2c97ce70c8d.overview_page.pb
# Dumped tool data for input_pipeline.pb to ../tblogs/age_model_22-12-15_01-01/train/plugins/profile/2022_12_15_01_01_56/a2c97ce70c8d.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to ../tblogs/age_model_22-12-15_01-01/train/plugins/profile/2022_12_15_01_01_56/a2c97ce70c8d.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to ../tblogs/age_model_22-12-15_01-01/train/plugins/profile/2022_12_15_01_01_56/a2c97ce70c8d.kernel_stats.pb
# 297/297 [==============================] - 177s 555ms/step - loss: 1.0380 - sparse_categorical_accuracy: 0.7927 - val_loss: 0.4171 - val_sparse_categorical_accuracy: 0.8198
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.81983, saving model to ./models/age_best_model.h5
# Epoch 2/60
# 297/297 [==============================] - 91s 306ms/step - loss: 0.3085 - sparse_categorical_accuracy: 0.8621 - val_loss: 0.4131 - val_sparse_categorical_accuracy: 0.8078
#
# Epoch 00002: val_sparse_categorical_accuracy did not improve from 0.81983
# Epoch 3/60
# 297/297 [==============================] - 83s 278ms/step - loss: 0.2766 - sparse_categorical_accuracy: 0.8787 - val_loss: 0.3190 - val_sparse_categorical_accuracy: 0.8638
#
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.81983 to 0.86381, saving model to ./models/age_best_model.h5
# Epoch 4/60
# 297/297 [==============================] - 88s 295ms/step - loss: 0.2415 - sparse_categorical_accuracy: 0.8977 - val_loss: 0.3289 - val_sparse_categorical_accuracy: 0.8638
#
# Epoch 00004: val_sparse_categorical_accuracy did not improve from 0.86381
# Epoch 5/60
# 297/297 [==============================] - 89s 300ms/step - loss: 0.2269 - sparse_categorical_accuracy: 0.9037 - val_loss: 0.3258 - val_sparse_categorical_accuracy: 0.8756
#
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.86381 to 0.87556, saving model to ./models/age_best_model.h5
# Epoch 6/60
# 297/297 [==============================] - 90s 302ms/step - loss: 0.2020 - sparse_categorical_accuracy: 0.9153 - val_loss: 0.3171 - val_sparse_categorical_accuracy: 0.8701
#
# Epoch 00006: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 7/60
# 297/297 [==============================] - 90s 304ms/step - loss: 0.1881 - sparse_categorical_accuracy: 0.9220 - val_loss: 0.3057 - val_sparse_categorical_accuracy: 0.8732
#
# Epoch 00007: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 8/60
# 297/297 [==============================] - 91s 305ms/step - loss: 0.1583 - sparse_categorical_accuracy: 0.9370 - val_loss: 0.3576 - val_sparse_categorical_accuracy: 0.8656
#
# Epoch 00008: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 9/60
# 297/297 [==============================] - 90s 302ms/step - loss: 0.1478 - sparse_categorical_accuracy: 0.9388 - val_loss: 0.3778 - val_sparse_categorical_accuracy: 0.8692
#
# Epoch 00009: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 10/60
# 297/297 [==============================] - 90s 304ms/step - loss: 0.1296 - sparse_categorical_accuracy: 0.9483 - val_loss: 0.3888 - val_sparse_categorical_accuracy: 0.8683
#
# Epoch 00010: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 11/60
# 297/297 [==============================] - 79s 264ms/step - loss: 0.1435 - sparse_categorical_accuracy: 0.9421 - val_loss: 0.4030 - val_sparse_categorical_accuracy: 0.8551
#
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 12/60
# 297/297 [==============================] - 89s 298ms/step - loss: 0.1254 - sparse_categorical_accuracy: 0.9508 - val_loss: 0.4336 - val_sparse_categorical_accuracy: 0.8753
#
# Epoch 00012: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 13/60
# 297/297 [==============================] - 88s 295ms/step - loss: 0.1026 - sparse_categorical_accuracy: 0.9606 - val_loss: 0.4567 - val_sparse_categorical_accuracy: 0.8701
#
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 14/60
# 297/297 [==============================] - 87s 291ms/step - loss: 0.0973 - sparse_categorical_accuracy: 0.9622 - val_loss: 0.5670 - val_sparse_categorical_accuracy: 0.8623
#
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 15/60
# 297/297 [==============================] - 89s 301ms/step - loss: 0.1032 - sparse_categorical_accuracy: 0.9589 - val_loss: 0.3608 - val_sparse_categorical_accuracy: 0.8732
#
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 16/60
# 297/297 [==============================] - 87s 293ms/step - loss: 0.0822 - sparse_categorical_accuracy: 0.9690 - val_loss: 0.6412 - val_sparse_categorical_accuracy: 0.8638
#
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 17/60
# 297/297 [==============================] - 88s 296ms/step - loss: 0.0801 - sparse_categorical_accuracy: 0.9692 - val_loss: 0.5771 - val_sparse_categorical_accuracy: 0.8747
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 18/60
# 297/297 [==============================] - 87s 293ms/step - loss: 0.0820 - sparse_categorical_accuracy: 0.9678 - val_loss: 0.5059 - val_sparse_categorical_accuracy: 0.8632
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 19/60
# 297/297 [==============================] - 79s 266ms/step - loss: 0.0752 - sparse_categorical_accuracy: 0.9707 - val_loss: 0.6506 - val_sparse_categorical_accuracy: 0.8563
#
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 20/60
# 297/297 [==============================] - 87s 292ms/step - loss: 0.0654 - sparse_categorical_accuracy: 0.9736 - val_loss: 0.6055 - val_sparse_categorical_accuracy: 0.8726
#
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 21/60
# 297/297 [==============================] - 87s 294ms/step - loss: 0.0666 - sparse_categorical_accuracy: 0.9740 - val_loss: 0.6535 - val_sparse_categorical_accuracy: 0.8719
#
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 22/60
# 297/297 [==============================] - 86s 289ms/step - loss: 0.0591 - sparse_categorical_accuracy: 0.9779 - val_loss: 0.5412 - val_sparse_categorical_accuracy: 0.8674
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 23/60
# 297/297 [==============================] - 86s 291ms/step - loss: 0.0569 - sparse_categorical_accuracy: 0.9779 - val_loss: 0.6358 - val_sparse_categorical_accuracy: 0.8695
#
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 24/60
# 297/297 [==============================] - 88s 296ms/step - loss: 0.0697 - sparse_categorical_accuracy: 0.9730 - val_loss: 0.6917 - val_sparse_categorical_accuracy: 0.8593
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.87556
# Epoch 25/60
# 297/297 [==============================] - 84s 284ms/step - loss: 0.0678 - sparse_categorical_accuracy: 0.9742 - val_loss: 0.6491 - val_sparse_categorical_accuracy: 0.8810
#
# Epoch 00025: val_sparse_categorical_accuracy improved from 0.87556 to 0.88099, saving model to ./models/age_best_model.h5
# Epoch 26/60
# 297/297 [==============================] - 87s 292ms/step - loss: 0.0654 - sparse_categorical_accuracy: 0.9750 - val_loss: 0.4842 - val_sparse_categorical_accuracy: 0.8780
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 27/60
# 297/297 [==============================] - 80s 269ms/step - loss: 0.0565 - sparse_categorical_accuracy: 0.9782 - val_loss: 0.6056 - val_sparse_categorical_accuracy: 0.8394
#
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 28/60
# 297/297 [==============================] - 86s 288ms/step - loss: 0.0531 - sparse_categorical_accuracy: 0.9800 - val_loss: 0.5889 - val_sparse_categorical_accuracy: 0.8707
#
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 29/60
# 297/297 [==============================] - 86s 291ms/step - loss: 0.0417 - sparse_categorical_accuracy: 0.9850 - val_loss: 0.6350 - val_sparse_categorical_accuracy: 0.8738
#
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 30/60
# 297/297 [==============================] - 87s 294ms/step - loss: 0.0367 - sparse_categorical_accuracy: 0.9860 - val_loss: 0.6665 - val_sparse_categorical_accuracy: 0.8735
#
# Epoch 00030: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 31/60
# 297/297 [==============================] - 87s 291ms/step - loss: 0.0510 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.5731 - val_sparse_categorical_accuracy: 0.8668
#
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 32/60
# 297/297 [==============================] - 87s 293ms/step - loss: 0.0361 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.7315 - val_sparse_categorical_accuracy: 0.8741
#
# Epoch 00032: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 33/60
# 297/297 [==============================] - 85s 287ms/step - loss: 0.0650 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.5840 - val_sparse_categorical_accuracy: 0.8774
#
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 34/60
# 297/297 [==============================] - 87s 292ms/step - loss: 0.0315 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.6361 - val_sparse_categorical_accuracy: 0.8707
#
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 35/60
# 297/297 [==============================] - 77s 260ms/step - loss: 0.0352 - sparse_categorical_accuracy: 0.9875 - val_loss: 0.8452 - val_sparse_categorical_accuracy: 0.8638
#
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 36/60
# 297/297 [==============================] - 86s 289ms/step - loss: 0.0555 - sparse_categorical_accuracy: 0.9787 - val_loss: 0.6922 - val_sparse_categorical_accuracy: 0.8692
#
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 37/60
# 297/297 [==============================] - 87s 292ms/step - loss: 0.0288 - sparse_categorical_accuracy: 0.9892 - val_loss: 0.8297 - val_sparse_categorical_accuracy: 0.8575
#
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 38/60
# 297/297 [==============================] - 82s 276ms/step - loss: 0.0343 - sparse_categorical_accuracy: 0.9874 - val_loss: 0.6156 - val_sparse_categorical_accuracy: 0.8653
#
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 39/60
# 297/297 [==============================] - 83s 280ms/step - loss: 0.0372 - sparse_categorical_accuracy: 0.9858 - val_loss: 0.6439 - val_sparse_categorical_accuracy: 0.8744
#
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 40/60
# 297/297 [==============================] - 86s 291ms/step - loss: 0.0512 - sparse_categorical_accuracy: 0.9809 - val_loss: 0.5694 - val_sparse_categorical_accuracy: 0.8735
#
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 41/60
# 297/297 [==============================] - 86s 290ms/step - loss: 0.0501 - sparse_categorical_accuracy: 0.9802 - val_loss: 0.5605 - val_sparse_categorical_accuracy: 0.8777
#
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 42/60
# 297/297 [==============================] - 87s 292ms/step - loss: 0.0326 - sparse_categorical_accuracy: 0.9864 - val_loss: 0.7925 - val_sparse_categorical_accuracy: 0.8695
#
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 43/60
# 297/297 [==============================] - 77s 259ms/step - loss: 0.0670 - sparse_categorical_accuracy: 0.9745 - val_loss: 0.6502 - val_sparse_categorical_accuracy: 0.8753
#
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 44/60
# 297/297 [==============================] - 86s 289ms/step - loss: 0.0381 - sparse_categorical_accuracy: 0.9859 - val_loss: 0.7907 - val_sparse_categorical_accuracy: 0.8629
#
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 45/60
# 297/297 [==============================] - 85s 286ms/step - loss: 0.0307 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.5964 - val_sparse_categorical_accuracy: 0.8756
#
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 46/60
# 297/297 [==============================] - 82s 277ms/step - loss: 0.0299 - sparse_categorical_accuracy: 0.9887 - val_loss: 0.6272 - val_sparse_categorical_accuracy: 0.8777
#
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 47/60
# 297/297 [==============================] - 84s 281ms/step - loss: 0.0316 - sparse_categorical_accuracy: 0.9881 - val_loss: 0.7901 - val_sparse_categorical_accuracy: 0.8732
#
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 48/60
# 297/297 [==============================] - 86s 290ms/step - loss: 0.0369 - sparse_categorical_accuracy: 0.9867 - val_loss: 0.6020 - val_sparse_categorical_accuracy: 0.8765
#
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 49/60
# 297/297 [==============================] - 82s 275ms/step - loss: 0.0334 - sparse_categorical_accuracy: 0.9874 - val_loss: 0.7280 - val_sparse_categorical_accuracy: 0.8713
#
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 50/60
# 297/297 [==============================] - 87s 291ms/step - loss: 0.0242 - sparse_categorical_accuracy: 0.9905 - val_loss: 1.1946 - val_sparse_categorical_accuracy: 0.8292
#
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 51/60
# 297/297 [==============================] - 78s 262ms/step - loss: 0.0307 - sparse_categorical_accuracy: 0.9879 - val_loss: 0.9816 - val_sparse_categorical_accuracy: 0.7999
#
# Epoch 00051: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 52/60
# 297/297 [==============================] - 85s 287ms/step - loss: 0.0349 - sparse_categorical_accuracy: 0.9864 - val_loss: 0.7448 - val_sparse_categorical_accuracy: 0.8756
#
# Epoch 00052: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 53/60
# 297/297 [==============================] - 84s 283ms/step - loss: 0.0336 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.6435 - val_sparse_categorical_accuracy: 0.8765
#
# Epoch 00053: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 54/60
# 297/297 [==============================] - 82s 277ms/step - loss: 0.0295 - sparse_categorical_accuracy: 0.9888 - val_loss: 0.5433 - val_sparse_categorical_accuracy: 0.8659
#
# Epoch 00054: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 55/60
# 297/297 [==============================] - 87s 292ms/step - loss: 0.0287 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.8502 - val_sparse_categorical_accuracy: 0.8674
#
# Epoch 00055: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 56/60
# 297/297 [==============================] - 85s 286ms/step - loss: 0.0247 - sparse_categorical_accuracy: 0.9898 - val_loss: 0.8316 - val_sparse_categorical_accuracy: 0.8683
#
# Epoch 00056: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 57/60
# 297/297 [==============================] - 84s 284ms/step - loss: 0.0246 - sparse_categorical_accuracy: 0.9909 - val_loss: 0.7036 - val_sparse_categorical_accuracy: 0.8804
#
# Epoch 00057: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 58/60
# 297/297 [==============================] - 87s 292ms/step - loss: 0.0262 - sparse_categorical_accuracy: 0.9903 - val_loss: 0.7681 - val_sparse_categorical_accuracy: 0.8704
#
# Epoch 00058: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 59/60
# 297/297 [==============================] - 78s 263ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9942 - val_loss: 0.8790 - val_sparse_categorical_accuracy: 0.8647
#
# Epoch 00059: val_sparse_categorical_accuracy did not improve from 0.88099
# Epoch 60/60
# 297/297 [==============================] - 84s 282ms/step - loss: 0.0406 - sparse_categorical_accuracy: 0.9843 - val_loss: 0.7037 - val_sparse_categorical_accuracy: 0.8747
#
# Epoch 00060: val_sparse_categorical_accuracy did not improve from 0.88099

# %% [markdown]
# ### Plot Training and Validation Loss

# %%
# print keys 
history.history.keys()
# Out:
# dict_keys(['loss', 'sparse_categorical_accuracy', 'val_loss', 'val_sparse_categorical_accuracy'])

# %%
NR_EPOCHS = len(history.history['loss'])
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(NR_EPOCHS)
plt.plot(epochs, loss_train, 'b', label='Training loss')
plt.plot(epochs, loss_val, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
accuracy_train = history.history['sparse_categorical_accuracy']
accuracy_val = history.history['val_sparse_categorical_accuracy']
epochs = range(NR_EPOCHS)
plt.plot(epochs, accuracy_train, 'b', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'orange', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Load model and validate

# %%
model_age = load_model("./models/age_best_model.h5")
loss, acc = model_age.evaluate(test_generator)
print (loss, acc)
# Out:
# 23/23 [==============================] - 11s 496ms/step - loss: 0.5161 - sparse_categorical_accuracy: 0.8862
# 0.516060471534729 0.8861560225486755

# %% [markdown]
# ### Show sample results

# %%
gen_dict = {0:'0', 1:'1'}

# %%
def show_faces(images, age=None, pred_age=None):
    plt.figure(figsize=(10,10))
    labels = {"Gender": [pred_age, age]}
    for i in range(16):
        plt.subplot(4,4, i+1)
        plt.axis('off')
        #plt.xticks([])
        #plt.yticks([])
        #plt.grid(False)
        plt.imshow(images[i])
        
        if pred_age[i] is None:
            continue
           
            
        real_age = int(age[i])
        predicted_age = np.argmax(predicted[i])
                
                
        plt.title(f"Gender Class: {gen_dict[real_age]}\n Gender Age Class: {gen_dict[predicted_age]}", fontsize=8)
            
        plt.subplots_adjust(wspace=0.3)

sample_validation_images, sample_validation_labels = next(test_generator)
predicted = model_age.predict(sample_validation_images)
show_faces(sample_validation_images, age=sample_validation_labels, pred_age=predicted)

# %% [markdown]
# ## Direct Age Estimation

# %%
def predictor(filename) :
    test_image = filename
    image_result = Image.open(test_image)
    # test_image = image.load_img(test_image, target_size=(100,100))
    test_image = image.load_img(test_image, target_size=(224,224,3))
    test_image = image.img_to_array(test_image)
    test_image = test_image/255
    test_image = np.expand_dims(test_image, axis=0)
    result = model_age.predict(test_image)
    r = np.max(result)
    per = r*100
    percentage = round(per,4)
    categories = ['0','1']
    image_result = plt.imshow(image_result)
    output = categories[np.argmax(result)]
    output = np.argmax(result)

    return result,percentage,output
EMOTION_DETECTOR = predictor('/kaggle/input/utkface-new/UTKFace/10_0_0_20170110221811823.jpg.chip.jpg')
print(EMOTION_DETECTOR)
# Out:
# (array([[1.0000000e+00, 5.9997264e-11]], dtype=float32), 100.0, 0)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
sample_validation_images, sample_validation_labels = next(test_generator)
predict_x=model_age.predict(sample_validation_images) 
results=np.argmax(predict_x,axis=1)
cm = confusion_matrix(sample_validation_labels, results)
cm_plot_labels = ['0','1']

cm_df = pd.DataFrame(cm, index = cm_plot_labels,
                     columns = cm_plot_labels
                    )
final_cm = cm_df
plt.figure(figsize = (5,5))
sns.heatmap(final_cm, annot = True,cmap='Greys',cbar=False,linewidth=2,fmt='d')
plt.title('CNN Emotion Classify UTK-Gender-VGG19')
plt.ylabel('True class')
plt.xlabel('Prediction class')
plt.show()

# %%
print('\t\tClassification Report For UTK-Gender-VGG19\n', classification_report(sample_validation_labels, results,target_names=cm_plot_labels))
# Out:
# 		Classification Report For UTK-Gender-VGG19
#                precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89        33
#            1       0.88      0.90      0.89        31
#
#     accuracy                           0.89        64
#    macro avg       0.89      0.89      0.89        64
# weighted avg       0.89      0.89      0.89        64

# %% [markdown]
# ### Load and build model

# %% [markdown]
# ### Plot Training and Validation Loss
