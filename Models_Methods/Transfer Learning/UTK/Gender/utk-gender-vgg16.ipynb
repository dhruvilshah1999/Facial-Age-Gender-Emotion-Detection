# %% [markdown]
# # Age Estimation using VGG16

# %%
from keras.layers import Input, Lambda, Dense, Flatten
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from tensorflow.keras.models import load_model

import numpy as np
from glob import glob
import matplotlib.pyplot as plt
import tensorflow as tf
from collections import Counter
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
from sklearn.utils import shuffle

import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns

from tqdm.notebook import tqdm

# %matplotlib inline

from PIL import Image
import shutil

# %% [markdown]
# ## Age estimation in age groups

# %% [markdown]
# ### Set image size and variables

# %%
IMAGE_SIZE = [224,224]
TRAIN_TEST_SPLIT = 0.3
BASE_DIR = '../input/utkface-new/UTKFace/'
NR_EPOCHS = 60

# %% [markdown]
# ### Define methods map direct age to classes

# %%
def age_to_class( age ):
    age_class = None
    if 0 <= age <= 20:
        age_class = 0
    if 20 < age <= 25:
        age_class = 1
    if 25 < age <= 30:
        age_class = 2
    if 30 < age <= 40:
        age_class = 3
    if 40 < age <= 60:
        age_class = 4
    if age > 60:
        age_class = 5
    return age_class

age_dict = {0:'0-20', 1:'20-25',2:'25-30', 3:'30-40', 4:'40-60', 5:'60+'}

def decode_age_label(age_id):
    return age_dict[int(age_id)]

# %% [markdown]
# ### Read input dataset

# %%
# read labels of image age, gender
image_paths = []
age_labels = []
gender_labels =[]
age_class = []

for filename in tqdm(os.listdir(BASE_DIR)):
  #read image path
  image_path = os.path.join(BASE_DIR, filename)
  #split filename to extract labels
  temp= filename.split('_')
  age = int(temp[0])
  gender = int(temp[1])
  image_paths.append(image_path)
  age_labels.append(age)
  gender_labels.append(gender)
  age_class.append(age_to_class(age))

# extract name of file 
names = []
for path in image_paths:
  temp = path.split('/')
  names.append(temp[4])

#convert to dataframe
df = pd.DataFrame()
df['image'], df['age'], df['gender'], df['age_class'], df['name'] = image_paths, age_labels, gender_labels, age_class, names
df.head()
df

# get and print the number of images in dataframe
age_verbose = [age_dict[int(age)] for age in df['age_class']]

print(Counter(age_verbose))
# Out:
#   0%|          | 0/23708 [00:00<?, ?it/s]
# Counter({'25-30': 5024, '0-20': 4877, '30-40': 4339, '40-60': 4311, '20-25': 2760, '60+': 2397})

# %% [markdown]
# ### Shuffle dataset

# %%
# shuffle dataset 
df = shuffle(df)

# %%
# check dataframe
df
# Out:
#                                                    image  age  gender  \
# 10778  ../input/utkface-new/UTKFace/28_0_3_2017011919...   28       0
# 11849  ../input/utkface-new/UTKFace/80_0_0_2017011121...   80       0
# 4039   ../input/utkface-new/UTKFace/31_1_1_2017011301...   31       1
# 2210   ../input/utkface-new/UTKFace/35_1_1_2017011300...   35       1
# 20519  ../input/utkface-new/UTKFace/25_0_4_2017011318...   25       0
# ...                                                  ...  ...     ...
# 23516  ../input/utkface-new/UTKFace/49_1_3_2017010914...   49       1
# 17061  ../input/utkface-new/UTKFace/35_0_0_2017011713...   35       0
# 7487   ../input/utkface-new/UTKFace/32_1_2_2017010318...   32       1
# 11767  ../input/utkface-new/UTKFace/67_0_0_2017010421...   67       0
# 492    ../input/utkface-new/UTKFace/27_1_2_2017011616...   27       1
#
#        age_class                                   name
# 10778          2  28_0_3_20170119194510875.jpg.chip.jpg
# 11849          5  80_0_0_20170111210128898.jpg.chip.jpg
# 4039           3  31_1_1_20170113012714175.jpg.chip.jpg
# 2210           3  35_1_1_20170113005348678.jpg.chip.jpg
# 20519          1  25_0_4_20170113180523812.jpg.chip.jpg
# ...          ...                                    ...
# 23516          4  49_1_3_20170109141810902.jpg.chip.jpg
# 17061          3  35_0_0_20170117134947221.jpg.chip.jpg
# 7487           3  32_1_2_20170103183806483.jpg.chip.jpg
# 11767          5  67_0_0_20170104212901716.jpg.chip.jpg
# 492            2  27_1_2_20170116162949938.jpg.chip.jpg
#
# [23708 rows x 5 columns]

# %% [markdown]
# ### Split Dataset into validation and test set

# %%
training_data = df.sample(frac=0.8, random_state=25)
temp = df.drop(training_data.index)


val_data =  temp.sample(frac=0.7, random_state=25)
testing_data = temp.drop(val_data.index)

 
print(f"No. of training examples: {training_data.shape[0]}")
print(f"No. of training examples: {val_data.shape[0]}")
print(f"No. of testing examples: {testing_data.shape[0]}")
# Out:
# No. of training examples: 18966
# No. of training examples: 3319
# No. of testing examples: 1423

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator


train_datagen = ImageDataGenerator(rescale=1./255,
                               preprocessing_function=preprocess_input)

val_datagen = ImageDataGenerator(rescale=1./255,
                                preprocessing_function=preprocess_input)


CLASS_MODE = 'raw'
BATCH_SIZE = 64
BASE_DIR = '../input/utkface-new/UTKFace'

train_generator = train_datagen.flow_from_dataframe(dataframe=training_data, 
                                                directory=BASE_DIR, 
                                                x_col='name', 
                                                y_col='gender', 
                                                class_mode=CLASS_MODE,
                                                batch_size=BATCH_SIZE, 
                                                shuffle=True, 
                                                target_size=IMAGE_SIZE)



val_generator = val_datagen.flow_from_dataframe(dataframe=val_data, 
                                              directory=BASE_DIR, 
                                              x_col='name', 
                                              y_col='gender', 
                                              class_mode=CLASS_MODE, 
                                              batch_size=BATCH_SIZE,
                                              shuffle=False, 
                                              target_size=IMAGE_SIZE)

test_generator = val_datagen.flow_from_dataframe(dataframe=testing_data, 
                                              directory=BASE_DIR, 
                                              x_col='name', 
                                              y_col='gender', 
                                              class_mode=CLASS_MODE, 
                                              batch_size=BATCH_SIZE,
                                              shuffle=False, 
                                              target_size=IMAGE_SIZE)
# Out:
# Found 18966 validated image filenames.
# Found 3319 validated image filenames.
# Found 1423 validated image filenames.

# %%
from pathlib import Path
path = Path("./models")
path.mkdir(exist_ok=True)


MODEL_PATH = "./models/age_best_model.h5"


checkpoint = tf.keras.callbacks.ModelCheckpoint(MODEL_PATH, 
                                                monitor='val_sparse_categorical_accuracy', 
                                                verbose=1, 
                                                save_best_only=True, 
                                                mode='max')

import datetime
log_dir = '../tblogs/age_model_' + datetime.datetime.now().strftime('%y-%m-%d_%H-%M')
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=0)
# Out:
# 2022-12-14 23:48:01.262104: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-12-14 23:48:01.262143: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
# 2022-12-14 23:48:01.351546: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1614] Profiler found 1 GPUs
# 2022-12-14 23:48:01.389968: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-12-14 23:48:01.390144: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed

# %% [markdown]
# ### Build and load Model

# %%
# # detect and init the TPU
# tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect()

# # instantiate a distribution strategy
# tpu_strategy = tf.distribute.experimental.TPUStrategy(tpu)

# %%
# load VGG16 without the last 3 Dense layers, in order to train these new
vgg = VGG16(input_shape = IMAGE_SIZE + [3], weights='imagenet', include_top=False)

# check if input type is correct
vgg.inputs
# Out:
# 2022-12-14 23:48:01.564969: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 23:48:01.678550: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 23:48:01.679369: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 23:48:01.680318: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-14 23:48:01.680647: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 23:48:01.681407: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 23:48:01.682062: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 23:48:04.036765: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 23:48:04.037673: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 23:48:04.038379: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-12-14 23:48:04.039008: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# [<KerasTensor: shape=(None, 224, 224, 3) dtype=float32 (created by layer 'input_1')>]

# %%
from keras.layers import *
for layer in vgg.layers:
  layer.trainable = False


x = Flatten()(vgg.output)
x = Dense(4096, activation='relu')(x)
x = Dense(4096, activation='relu')(x)
prediction = Dense(2, activation='softmax')(x)
model = Model(inputs=vgg.input, outputs=prediction)
    
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=[tf.keras.metrics.SparseCategoricalAccuracy()])

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 4096)              102764544
# _________________________________________________________________
# dense_1 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 8194
# =================================================================
# Total params: 134,268,738
# Trainable params: 119,554,050
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras import callbacks

earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 5, 
                                        restore_best_weights = True)

history = model.fit(train_generator,
                    epochs=NR_EPOCHS,
                    validation_data=val_generator,
                    callbacks = [tensorboard_callback, checkpoint]
                    )
# Out:
# 2022-12-14 23:48:05.695088: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/60
# 2022-12-14 23:48:07.703626: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
#   1/297 [..............................] - ETA: 1:00:50 - loss: 0.6895 - sparse_categorical_accuracy: 0.4844
# 2022-12-14 23:48:18.098324: I tensorflow/core/profiler/lib/profiler_session.cc:131] Profiler session initializing.
# 2022-12-14 23:48:18.098790: I tensorflow/core/profiler/lib/profiler_session.cc:146] Profiler session started.
#   2/297 [..............................] - ETA: 2:49 - loss: 2.3388 - sparse_categorical_accuracy: 0.5703
# 2022-12-14 23:48:18.642264: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-12-14 23:48:18.642737: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1748] CUPTI activity buffer flushed
# 2022-12-14 23:48:18.781922: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:673]  GpuTracer has collected 145 callback api events and 142 activity events.
# 2022-12-14 23:48:18.789206: I tensorflow/core/profiler/lib/profiler_session.cc:164] Profiler session tear down.
# 2022-12-14 23:48:18.805597: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ../tblogs/age_model_22-12-14_23-48/train/plugins/profile/2022_12_14_23_48_18
#
# 2022-12-14 23:48:18.809551: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to ../tblogs/age_model_22-12-14_23-48/train/plugins/profile/2022_12_14_23_48_18/9443e5b05a9c.trace.json.gz
# 2022-12-14 23:48:18.829179: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: ../tblogs/age_model_22-12-14_23-48/train/plugins/profile/2022_12_14_23_48_18
#
# 2022-12-14 23:48:18.830703: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to ../tblogs/age_model_22-12-14_23-48/train/plugins/profile/2022_12_14_23_48_18/9443e5b05a9c.memory_profile.json.gz
# 2022-12-14 23:48:18.831345: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: ../tblogs/age_model_22-12-14_23-48/train/plugins/profile/2022_12_14_23_48_18
# Dumped tool data for xplane.pb to ../tblogs/age_model_22-12-14_23-48/train/plugins/profile/2022_12_14_23_48_18/9443e5b05a9c.xplane.pb
# Dumped tool data for overview_page.pb to ../tblogs/age_model_22-12-14_23-48/train/plugins/profile/2022_12_14_23_48_18/9443e5b05a9c.overview_page.pb
# Dumped tool data for input_pipeline.pb to ../tblogs/age_model_22-12-14_23-48/train/plugins/profile/2022_12_14_23_48_18/9443e5b05a9c.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to ../tblogs/age_model_22-12-14_23-48/train/plugins/profile/2022_12_14_23_48_18/9443e5b05a9c.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to ../tblogs/age_model_22-12-14_23-48/train/plugins/profile/2022_12_14_23_48_18/9443e5b05a9c.kernel_stats.pb
# 297/297 [==============================] - 152s 472ms/step - loss: 1.1230 - sparse_categorical_accuracy: 0.8187 - val_loss: 0.3177 - val_sparse_categorical_accuracy: 0.8530
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.85297, saving model to ./models/age_best_model.h5
# Epoch 2/60
# 297/297 [==============================] - 85s 284ms/step - loss: 0.2607 - sparse_categorical_accuracy: 0.8887 - val_loss: 0.2694 - val_sparse_categorical_accuracy: 0.8837
#
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.85297 to 0.88370, saving model to ./models/age_best_model.h5
# Epoch 3/60
# 297/297 [==============================] - 75s 252ms/step - loss: 0.2162 - sparse_categorical_accuracy: 0.9080 - val_loss: 0.2520 - val_sparse_categorical_accuracy: 0.8912
#
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.88370 to 0.89123, saving model to ./models/age_best_model.h5
# Epoch 4/60
# 297/297 [==============================] - 84s 281ms/step - loss: 0.1949 - sparse_categorical_accuracy: 0.9175 - val_loss: 0.2994 - val_sparse_categorical_accuracy: 0.8783
#
# Epoch 00004: val_sparse_categorical_accuracy did not improve from 0.89123
# Epoch 5/60
# 297/297 [==============================] - 88s 295ms/step - loss: 0.1537 - sparse_categorical_accuracy: 0.9366 - val_loss: 0.3042 - val_sparse_categorical_accuracy: 0.8840
#
# Epoch 00005: val_sparse_categorical_accuracy did not improve from 0.89123
# Epoch 6/60
# 297/297 [==============================] - 83s 279ms/step - loss: 0.1452 - sparse_categorical_accuracy: 0.9423 - val_loss: 0.2769 - val_sparse_categorical_accuracy: 0.8888
#
# Epoch 00006: val_sparse_categorical_accuracy did not improve from 0.89123
# Epoch 7/60
# 297/297 [==============================] - 82s 277ms/step - loss: 0.1254 - sparse_categorical_accuracy: 0.9523 - val_loss: 0.2958 - val_sparse_categorical_accuracy: 0.8948
#
# Epoch 00007: val_sparse_categorical_accuracy improved from 0.89123 to 0.89485, saving model to ./models/age_best_model.h5
# Epoch 8/60
# 297/297 [==============================] - 81s 272ms/step - loss: 0.1071 - sparse_categorical_accuracy: 0.9569 - val_loss: 0.3074 - val_sparse_categorical_accuracy: 0.8882
#
# Epoch 00008: val_sparse_categorical_accuracy did not improve from 0.89485
# Epoch 9/60
# 297/297 [==============================] - 83s 279ms/step - loss: 0.1013 - sparse_categorical_accuracy: 0.9605 - val_loss: 0.3653 - val_sparse_categorical_accuracy: 0.8961
#
# Epoch 00009: val_sparse_categorical_accuracy improved from 0.89485 to 0.89605, saving model to ./models/age_best_model.h5
# Epoch 10/60
# 297/297 [==============================] - 86s 290ms/step - loss: 0.0792 - sparse_categorical_accuracy: 0.9718 - val_loss: 0.4315 - val_sparse_categorical_accuracy: 0.8891
#
# Epoch 00010: val_sparse_categorical_accuracy did not improve from 0.89605
# Epoch 11/60
# 297/297 [==============================] - 70s 235ms/step - loss: 0.0737 - sparse_categorical_accuracy: 0.9712 - val_loss: 0.4061 - val_sparse_categorical_accuracy: 0.8888
#
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.89605
# Epoch 12/60
# 297/297 [==============================] - 83s 279ms/step - loss: 0.0772 - sparse_categorical_accuracy: 0.9714 - val_loss: 0.3600 - val_sparse_categorical_accuracy: 0.8979
#
# Epoch 00012: val_sparse_categorical_accuracy improved from 0.89605 to 0.89786, saving model to ./models/age_best_model.h5
# Epoch 13/60
# 297/297 [==============================] - 85s 284ms/step - loss: 0.0671 - sparse_categorical_accuracy: 0.9749 - val_loss: 0.3925 - val_sparse_categorical_accuracy: 0.8894
#
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 14/60
# 297/297 [==============================] - 84s 282ms/step - loss: 0.0614 - sparse_categorical_accuracy: 0.9775 - val_loss: 0.4151 - val_sparse_categorical_accuracy: 0.8942
#
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 15/60
# 297/297 [==============================] - 77s 259ms/step - loss: 0.0483 - sparse_categorical_accuracy: 0.9827 - val_loss: 0.4220 - val_sparse_categorical_accuracy: 0.8933
#
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 16/60
# 297/297 [==============================] - 81s 273ms/step - loss: 0.0557 - sparse_categorical_accuracy: 0.9795 - val_loss: 0.5128 - val_sparse_categorical_accuracy: 0.8807
#
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 17/60
# 297/297 [==============================] - 78s 262ms/step - loss: 0.0529 - sparse_categorical_accuracy: 0.9800 - val_loss: 0.4812 - val_sparse_categorical_accuracy: 0.8822
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 18/60
# 297/297 [==============================] - 74s 250ms/step - loss: 0.0407 - sparse_categorical_accuracy: 0.9862 - val_loss: 0.4095 - val_sparse_categorical_accuracy: 0.8921
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 19/60
# 297/297 [==============================] - 71s 239ms/step - loss: 0.0402 - sparse_categorical_accuracy: 0.9852 - val_loss: 0.6225 - val_sparse_categorical_accuracy: 0.8807
#
# Epoch 00019: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 20/60
# 297/297 [==============================] - 81s 273ms/step - loss: 0.0479 - sparse_categorical_accuracy: 0.9821 - val_loss: 0.4570 - val_sparse_categorical_accuracy: 0.8852
#
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 21/60
# 297/297 [==============================] - 82s 277ms/step - loss: 0.0280 - sparse_categorical_accuracy: 0.9894 - val_loss: 0.5376 - val_sparse_categorical_accuracy: 0.8750
#
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 22/60
# 297/297 [==============================] - 79s 266ms/step - loss: 0.0469 - sparse_categorical_accuracy: 0.9823 - val_loss: 0.5304 - val_sparse_categorical_accuracy: 0.8948
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 23/60
# 297/297 [==============================] - 79s 265ms/step - loss: 0.0356 - sparse_categorical_accuracy: 0.9867 - val_loss: 0.6211 - val_sparse_categorical_accuracy: 0.8828
#
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 24/60
# 297/297 [==============================] - 84s 283ms/step - loss: 0.0227 - sparse_categorical_accuracy: 0.9910 - val_loss: 0.6713 - val_sparse_categorical_accuracy: 0.8912
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 25/60
# 297/297 [==============================] - 78s 263ms/step - loss: 0.0290 - sparse_categorical_accuracy: 0.9894 - val_loss: 0.5666 - val_sparse_categorical_accuracy: 0.8873
#
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 26/60
# 297/297 [==============================] - 73s 246ms/step - loss: 0.0344 - sparse_categorical_accuracy: 0.9877 - val_loss: 0.6007 - val_sparse_categorical_accuracy: 0.8873
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 27/60
# 297/297 [==============================] - 79s 265ms/step - loss: 0.0319 - sparse_categorical_accuracy: 0.9879 - val_loss: 0.4990 - val_sparse_categorical_accuracy: 0.8882
#
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 28/60
# 297/297 [==============================] - 82s 275ms/step - loss: 0.0323 - sparse_categorical_accuracy: 0.9876 - val_loss: 0.5793 - val_sparse_categorical_accuracy: 0.8973
#
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 29/60
# 297/297 [==============================] - 81s 273ms/step - loss: 0.0235 - sparse_categorical_accuracy: 0.9916 - val_loss: 0.5192 - val_sparse_categorical_accuracy: 0.8945
#
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 30/60
# 297/297 [==============================] - 80s 268ms/step - loss: 0.0260 - sparse_categorical_accuracy: 0.9900 - val_loss: 0.5241 - val_sparse_categorical_accuracy: 0.8858
#
# Epoch 00030: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 31/60
# 297/297 [==============================] - 86s 290ms/step - loss: 0.0300 - sparse_categorical_accuracy: 0.9901 - val_loss: 0.5893 - val_sparse_categorical_accuracy: 0.8906
#
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 32/60
# 297/297 [==============================] - 81s 273ms/step - loss: 0.0189 - sparse_categorical_accuracy: 0.9932 - val_loss: 0.6718 - val_sparse_categorical_accuracy: 0.8915
#
# Epoch 00032: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 33/60
# 297/297 [==============================] - 77s 258ms/step - loss: 0.0254 - sparse_categorical_accuracy: 0.9914 - val_loss: 0.5772 - val_sparse_categorical_accuracy: 0.8970
#
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 34/60
# 297/297 [==============================] - 74s 249ms/step - loss: 0.0208 - sparse_categorical_accuracy: 0.9921 - val_loss: 0.6038 - val_sparse_categorical_accuracy: 0.8924
#
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 35/60
# 297/297 [==============================] - 69s 234ms/step - loss: 0.0127 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.9976 - val_sparse_categorical_accuracy: 0.8620
#
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 36/60
# 297/297 [==============================] - 81s 272ms/step - loss: 0.0242 - sparse_categorical_accuracy: 0.9910 - val_loss: 0.6031 - val_sparse_categorical_accuracy: 0.8930
#
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 37/60
# 297/297 [==============================] - 81s 274ms/step - loss: 0.0236 - sparse_categorical_accuracy: 0.9909 - val_loss: 0.6726 - val_sparse_categorical_accuracy: 0.8873
#
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 38/60
# 297/297 [==============================] - 79s 264ms/step - loss: 0.0124 - sparse_categorical_accuracy: 0.9952 - val_loss: 0.7339 - val_sparse_categorical_accuracy: 0.8967
#
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 39/60
# 297/297 [==============================] - 79s 266ms/step - loss: 0.0211 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.6525 - val_sparse_categorical_accuracy: 0.8918
#
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 40/60
# 297/297 [==============================] - 80s 269ms/step - loss: 0.0199 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.7161 - val_sparse_categorical_accuracy: 0.8961
#
# Epoch 00040: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 41/60
# 297/297 [==============================] - 77s 259ms/step - loss: 0.0130 - sparse_categorical_accuracy: 0.9951 - val_loss: 0.8538 - val_sparse_categorical_accuracy: 0.8816
#
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 42/60
# 297/297 [==============================] - 78s 262ms/step - loss: 0.0257 - sparse_categorical_accuracy: 0.9912 - val_loss: 0.6052 - val_sparse_categorical_accuracy: 0.8867
#
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 43/60
# 297/297 [==============================] - 77s 258ms/step - loss: 0.0179 - sparse_categorical_accuracy: 0.9937 - val_loss: 0.5880 - val_sparse_categorical_accuracy: 0.8939
#
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 44/60
# 297/297 [==============================] - 78s 262ms/step - loss: 0.0195 - sparse_categorical_accuracy: 0.9938 - val_loss: 0.5594 - val_sparse_categorical_accuracy: 0.8933
#
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 45/60
# 297/297 [==============================] - 76s 257ms/step - loss: 0.0154 - sparse_categorical_accuracy: 0.9940 - val_loss: 0.7049 - val_sparse_categorical_accuracy: 0.8882
#
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 46/60
# 297/297 [==============================] - 71s 237ms/step - loss: 0.0213 - sparse_categorical_accuracy: 0.9919 - val_loss: 0.6808 - val_sparse_categorical_accuracy: 0.8939
#
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 47/60
# 297/297 [==============================] - 80s 269ms/step - loss: 0.0173 - sparse_categorical_accuracy: 0.9939 - val_loss: 0.6460 - val_sparse_categorical_accuracy: 0.8921
#
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 48/60
# 297/297 [==============================] - 82s 276ms/step - loss: 0.0121 - sparse_categorical_accuracy: 0.9953 - val_loss: 0.6744 - val_sparse_categorical_accuracy: 0.8973
#
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 49/60
# 297/297 [==============================] - 81s 273ms/step - loss: 0.0191 - sparse_categorical_accuracy: 0.9927 - val_loss: 0.8634 - val_sparse_categorical_accuracy: 0.8780
#
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 50/60
# 297/297 [==============================] - 93s 315ms/step - loss: 0.0204 - sparse_categorical_accuracy: 0.9929 - val_loss: 0.7117 - val_sparse_categorical_accuracy: 0.8942
#
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 51/60
# 297/297 [==============================] - 134s 451ms/step - loss: 0.0080 - sparse_categorical_accuracy: 0.9969 - val_loss: 0.9188 - val_sparse_categorical_accuracy: 0.8930
#
# Epoch 00051: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 52/60
# 297/297 [==============================] - 136s 456ms/step - loss: 0.0136 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.7126 - val_sparse_categorical_accuracy: 0.8945
#
# Epoch 00052: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 53/60
# 297/297 [==============================] - 94s 318ms/step - loss: 0.0167 - sparse_categorical_accuracy: 0.9935 - val_loss: 0.8155 - val_sparse_categorical_accuracy: 0.8921
#
# Epoch 00053: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 54/60
# 297/297 [==============================] - 71s 238ms/step - loss: 0.0155 - sparse_categorical_accuracy: 0.9940 - val_loss: 0.7235 - val_sparse_categorical_accuracy: 0.8894
#
# Epoch 00054: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 55/60
# 297/297 [==============================] - 80s 268ms/step - loss: 0.0143 - sparse_categorical_accuracy: 0.9943 - val_loss: 0.9321 - val_sparse_categorical_accuracy: 0.8686
#
# Epoch 00055: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 56/60
# 297/297 [==============================] - 83s 278ms/step - loss: 0.0104 - sparse_categorical_accuracy: 0.9961 - val_loss: 0.8377 - val_sparse_categorical_accuracy: 0.8933
#
# Epoch 00056: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 57/60
# 297/297 [==============================] - 81s 274ms/step - loss: 0.0117 - sparse_categorical_accuracy: 0.9950 - val_loss: 0.7179 - val_sparse_categorical_accuracy: 0.8828
#
# Epoch 00057: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 58/60
# 297/297 [==============================] - 77s 260ms/step - loss: 0.0206 - sparse_categorical_accuracy: 0.9925 - val_loss: 0.7925 - val_sparse_categorical_accuracy: 0.8939
#
# Epoch 00058: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 59/60
# 297/297 [==============================] - 78s 263ms/step - loss: 0.0200 - sparse_categorical_accuracy: 0.9922 - val_loss: 0.7400 - val_sparse_categorical_accuracy: 0.8810
#
# Epoch 00059: val_sparse_categorical_accuracy did not improve from 0.89786
# Epoch 60/60
# 297/297 [==============================] - 77s 260ms/step - loss: 0.0089 - sparse_categorical_accuracy: 0.9962 - val_loss: 1.0365 - val_sparse_categorical_accuracy: 0.8713
#
# Epoch 00060: val_sparse_categorical_accuracy did not improve from 0.89786

# %% [markdown]
# ### Plot Training and Validation Loss

# %%
# print keys 
history.history.keys()
# Out:
# dict_keys(['loss', 'sparse_categorical_accuracy', 'val_loss', 'val_sparse_categorical_accuracy'])

# %%
NR_EPOCHS = len(history.history['loss'])
loss_train = history.history['loss']
loss_val = history.history['val_loss']
epochs = range(NR_EPOCHS)
plt.plot(epochs, loss_train, 'b', label='Training loss')
plt.plot(epochs, loss_val, 'orange', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
accuracy_train = history.history['sparse_categorical_accuracy']
accuracy_val = history.history['val_sparse_categorical_accuracy']
epochs = range(NR_EPOCHS)
plt.plot(epochs, accuracy_train, 'b', label='Training accuracy')
plt.plot(epochs, accuracy_val, 'orange', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ### Load model and validate

# %%
model_age = load_model("./models/age_best_model.h5")
loss, acc = model_age.evaluate(test_generator)
print (loss, acc)
# Out:
# 23/23 [==============================] - 9s 405ms/step - loss: 0.3381 - sparse_categorical_accuracy: 0.9016
# 0.33805379271507263 0.9016162753105164

# %% [markdown]
# ### Show sample results

# %%
gen_dict = {0:'0', 1:'1'}

# %%
def show_faces(images, age=None, pred_age=None):
    plt.figure(figsize=(10,10))
    labels = {"Gender": [pred_age, age]}
    for i in range(16):
        plt.subplot(4,4, i+1)
        plt.axis('off')
        #plt.xticks([])
        #plt.yticks([])
        #plt.grid(False)
        plt.imshow(images[i])
        
        if pred_age[i] is None:
            continue
           
            
        real_age = int(age[i])
        predicted_age = np.argmax(predicted[i])
                
                
        plt.title(f"Gender Class: {gen_dict[real_age]}\n Predicted Gender Class: {gen_dict[predicted_age]}", fontsize=8)
            
        plt.subplots_adjust(wspace=0.3)

sample_validation_images, sample_validation_labels = next(test_generator)
predicted = model_age.predict(sample_validation_images)
show_faces(sample_validation_images, age=sample_validation_labels, pred_age=predicted)

# %%
def predictor(filename) :
    test_image = filename
    image_result = Image.open(test_image)
    # test_image = image.load_img(test_image, target_size=(100,100))
    test_image = image.load_img(test_image, target_size=(224,224,3))
    test_image = image.img_to_array(test_image)
    test_image = test_image/255
    test_image = np.expand_dims(test_image, axis=0)
    result = model_age.predict(test_image)
    r = np.max(result)
    per = r*100
    percentage = round(per,4)
    categories = ['0','1']
    image_result = plt.imshow(image_result)
    output = categories[np.argmax(result)]
    output = np.argmax(result)

    return result,percentage,output
EMOTION_DETECTOR = predictor('/kaggle/input/utkface-new/UTKFace/100_1_0_20170119212053665.jpg.chip.jpg')
print(EMOTION_DETECTOR)
# Out:
# (array([[0.00099932, 0.9990007 ]], dtype=float32), 99.9001, 1)

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
sample_validation_images, sample_validation_labels = next(test_generator)
predict_x=model_age.predict(sample_validation_images) 
results=np.argmax(predict_x,axis=1)
cm = confusion_matrix(sample_validation_labels, results)
cm_plot_labels = ['0','1']

cm_df = pd.DataFrame(cm, index = cm_plot_labels,
                     columns = cm_plot_labels
                    )
final_cm = cm_df
plt.figure(figsize = (5,5))
sns.heatmap(final_cm, annot = True,cmap='Greys',cbar=False,linewidth=2,fmt='d')
plt.title('CNN Emotion Classify UTK-Gender-VGG16')
plt.ylabel('True class')
plt.xlabel('Prediction class')
plt.show()

# %%
print('\t\tClassification Report For UTK-Gender-VGG16\n', classification_report(sample_validation_labels, results,target_names=cm_plot_labels))
# Out:
# 		Classification Report For UTK-Gender-VGG16
#                precision    recall  f1-score   support
#
#            0       0.93      0.87      0.90        30
#            1       0.89      0.94      0.91        34
#
#     accuracy                           0.91        64
#    macro avg       0.91      0.90      0.91        64
# weighted avg       0.91      0.91      0.91        64

# %%
import sys

sys.version
# Out:
# '3.7.12 | packaged by conda-forge | (default, Oct 26 2021, 06:08:53) \n[GCC 9.4.0]'
